# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Read-data" data-toc-modified-id="1.-Read-data-1">1. Read data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Define-Raw-Categorical-&amp;-Raw-Numercial-features" data-toc-modified-id="Define-Raw-Categorical-&amp;-Raw-Numercial-features-1.0.0.1">Define Raw Categorical &amp; Raw Numercial features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#2.-Transform-data" data-toc-modified-id="2.-Transform-data-2">2. Transform data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#define-transformer" data-toc-modified-id="define-transformer-2.0.0.1">define transformer</a></span></li><li><span><a href="#apply-transfomer" data-toc-modified-id="apply-transfomer-2.0.0.2">apply transfomer</a></span></li><li><span><a href="#Use-case-:-case-of-a-shortlist" data-toc-modified-id="Use-case-:-case-of-a-shortlist-2.0.0.3">Use case : case of a shortlist</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#3.-Reduce-data-dimension" data-toc-modified-id="3.-Reduce-data-dimension-3">3. Reduce data dimension</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#define-PCA-reducer" data-toc-modified-id="define-PCA-reducer-3.0.0.1">define PCA reducer</a></span></li><li><span><a href="#apply-PCA-reducer" data-toc-modified-id="apply-PCA-reducer-3.0.0.2">apply PCA reducer</a></span></li><li><span><a href="#PCA-to-any-features-(both-numerical-and-categorical)" data-toc-modified-id="PCA-to-any-features-(both-numerical-and-categorical)-3.0.0.3">PCA to any features (both numerical and categorical)</a></span></li><li><span><a href="#PCA-to-numerical-features" data-toc-modified-id="PCA-to-numerical-features-3.0.0.4">PCA to numerical features</a></span></li><li><span><a href="#PCA-to-categorical-features" data-toc-modified-id="PCA-to-categorical-features-3.0.0.5">PCA to categorical features</a></span></li><li><span><a href="#use-case-:-PCA-to-the-shortlist" data-toc-modified-id="use-case-:-PCA-to-the-shortlist-3.0.0.6">use case : PCA to the shortlist</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#4.-Alternate-dimension-reducers" data-toc-modified-id="4.-Alternate-dimension-reducers-4">4. Alternate dimension reducers</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#4.1.-T-Distributed-Stochastic-Neighbouring-Entities-(t-SNE)" data-toc-modified-id="4.1.-T-Distributed-Stochastic-Neighbouring-Entities-(t-SNE)-4.0.1">4.1. T-Distributed Stochastic Neighbouring Entities (t-SNE)</a></span><ul class="toc-item"><li><span><a href="#t-SNE-to-any-features" data-toc-modified-id="t-SNE-to-any-features-4.0.1.1">t-SNE to any features</a></span></li><li><span><a href="#t-SNE-to-numerical-features" data-toc-modified-id="t-SNE-to-numerical-features-4.0.1.2">t-SNE to numerical features</a></span></li><li><span><a href="#t-SNE-to-categorical-features" data-toc-modified-id="t-SNE-to-categorical-features-4.0.1.3">t-SNE to categorical features</a></span></li><li><span><a href="#t-SNE-to-features-shortlist---Use-Case" data-toc-modified-id="t-SNE-to-features-shortlist---Use-Case-4.0.1.4">t-SNE to features shortlist - Use Case</a></span></li></ul></li><li><span><a href="#4.2.-UMAP" data-toc-modified-id="4.2.-UMAP-4.0.2">4.2. UMAP</a></span></li></ul></li></ul></li><li><span><a href="#5.-Cluster-data" data-toc-modified-id="5.-Cluster-data-5">5. Cluster data</a></span><ul class="toc-item"><li><span><a href="#5.1.-K-Means" data-toc-modified-id="5.1.-K-Means-5.1">5.1. K-Means</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#define-clusterer" data-toc-modified-id="define-clusterer-5.1.0.1">define clusterer</a></span></li></ul></li></ul></li><li><span><a href="#5.2.-Use-Case-:-K-Means-with-same-dim-reduction-(PCA-80%,-8-PCs)" data-toc-modified-id="5.2.-Use-Case-:-K-Means-with-same-dim-reduction-(PCA-80%,-8-PCs)-5.2">5.2. Use Case : K-Means with same dim reduction (PCA 80%, 8 PCs)</a></span></li><li><span><a href="#5.3.-K-Means-tuning" data-toc-modified-id="5.3.-K-Means-tuning-5.3">5.3. K-Means tuning</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#tuning-PCA-n_components" data-toc-modified-id="tuning-PCA-n_components-5.3.0.1">tuning PCA n_components</a></span></li></ul></li><li><span><a href="#nested-loops-to-parse-npca-components-and-nclust-clusters" data-toc-modified-id="nested-loops-to-parse-npca-components-and-nclust-clusters-5.3.1">nested loops to parse npca components and nclust clusters</a></span></li></ul></li><li><span><a href="#5.4.-K-Means-:-evaluation-of-alternate-reducer-t-SNE" data-toc-modified-id="5.4.-K-Means-:-evaluation-of-alternate-reducer-t-SNE-5.4">5.4. K-Means : evaluation of alternate reducer t-SNE</a></span></li></ul></li><li><span><a href="#6.-Alternate-clusterers" data-toc-modified-id="6.-Alternate-clusterers-6">6. Alternate clusterers</a></span><ul class="toc-item"><li><span><a href="#6.1.-HDBSCAN" data-toc-modified-id="6.1.-HDBSCAN-6.1">6.1. HDBSCAN</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#HDBSCAN-after-PCA-80%" data-toc-modified-id="HDBSCAN-after-PCA-80%-6.1.0.1">HDBSCAN after PCA 80%</a></span></li><li><span><a href="#HDBSCAN-after-PCA-2-PCs" data-toc-modified-id="HDBSCAN-after-PCA-2-PCs-6.1.0.2">HDBSCAN after PCA 2 PCs</a></span></li><li><span><a href="#HDBSCAN-after-t-SNE-2d-transformation" data-toc-modified-id="HDBSCAN-after-t-SNE-2d-transformation-6.1.0.3">HDBSCAN after t-SNE 2d transformation</a></span></li><li><span><a href="#HDBSCAN-after-no-transformation" data-toc-modified-id="HDBSCAN-after-no-transformation-6.1.0.4">HDBSCAN after no transformation</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#7.-Enhance-Actionability-through-K-Modes" data-toc-modified-id="7.-Enhance-Actionability-through-K-Modes-7">7. Enhance Actionability through K-Modes</a></span><ul class="toc-item"><li><span><a href="#7.1.-Build-a-rough-segmentation" data-toc-modified-id="7.1.-Build-a-rough-segmentation-7.1">7.1. Build a rough segmentation</a></span></li><li><span><a href="#7.2.-K-Modes-visualization" data-toc-modified-id="7.2.-K-Modes-visualization-7.2">7.2. K-Modes visualization</a></span></li><li><span><a href="#7.3.-Assess-K-Modes-stability-:-by-comparison-to-&quot;rising&quot;-(2017---baseline)" data-toc-modified-id="7.3.-Assess-K-Modes-stability-:-by-comparison-to-&quot;rising&quot;-(2017---baseline)-7.3">7.3. Assess K-Modes stability : by comparison to "rising" (2017 - baseline)</a></span></li></ul></li><li><span><a href="#8.-Explore-K-Prototype-to-adress-mixed-type-features" data-toc-modified-id="8.-Explore-K-Prototype-to-adress-mixed-type-features-8">8. Explore K-Prototype to adress mixed-type features</a></span><ul class="toc-item"><li><span><a href="#8.1.-Preprocess-Data" data-toc-modified-id="8.1.-Preprocess-Data-8.1">8.1. Preprocess Data</a></span></li><li><span><a href="#8.2-Perform-K-Prototype-on-entire-dataset" data-toc-modified-id="8.2-Perform-K-Prototype-on-entire-dataset-8.2">8.2 Perform K-Prototype on entire dataset</a></span></li><li><span><a href="#8.3.-Assess-stability---by-comparison-to-&quot;rising&quot;-(2017---baseline)" data-toc-modified-id="8.3.-Assess-stability---by-comparison-to-&quot;rising&quot;-(2017---baseline)-8.3">8.3. Assess stability - by comparison to "rising" (2017 - baseline)</a></span></li><li><span><a href="#8.4.-Assess-stability-:-dissimilarity-trend-after-aggregation" data-toc-modified-id="8.4.-Assess-stability-:-dissimilarity-trend-after-aggregation-8.4">8.4. Assess stability : dissimilarity trend after aggregation</a></span></li><li><span><a href="#8.5.-Assess-stability-versus-KMeans" data-toc-modified-id="8.5.-Assess-stability-versus-KMeans-8.5">8.5. Assess stability versus KMeans</a></span></li></ul></li></ul></div>

# %% [markdown]
# Rédigé par Etienne Lardeur
# 2020, Projet 5 parcours Data Scientist - OpenClassrooms

# %%
# %load_ext pycodestyle_magic
# %flake8_on
# PEP8 tested

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
from itertools import product
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.pipeline import Pipeline
from functions import heatmap2
from umap import UMAP
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes
import time
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# 9:80: E501 line too long (92 > 79 characters)
# 1: E999 SyntaxError: invalid syntax

# %%
# be sure to display any columns
pd.options.display.max_columns = 100

# %% [markdown]
# # 1. Read data

# %%
# read data
time_start = time.time()
data = pd.read_csv('Data/data.csv')
print('data imported, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# data imported, elapsed time: 1.5928370952606201 seconds

# %%
# index by customer_unique_id
data = data.rename(index=data['customer_unique_id'])

# %%
# type & nb of features
print(data.dtypes.unique())
print(data.columns.size)
# Out:
# [dtype('O') dtype('int64') dtype('float64')]
# 78

# %%
# track numerical features to keep those not to transform
data.select_dtypes(include='number').columns
# Out:
# Index(['order_purchase_year', 'order_purchase_month', 'order_purchase_day',
#        'order_purchase_dayofweek', 'order_purchase_hour',
#        'estimated_delivery_time', 'effective_delivery_time',
#        'delivery_vs_estimated', 'total_price', 'total_freight',
#        'freight_percentage', 'charm_price', 'product_price', 'product_freight',
#        'product_name_length', 'product_description_length',
#        'product_photos_qty', 'product_weight_g', 'product_size',
#        'product_qlty_index', 'product_density', 'main_payment_value',
#        'payment_sequence_size', 'payment_installments_size', 'payment_total',
#        'seller_lat', 'seller_lng', 'order_count', 'customer_lat',
#        'customer_lng', 'cust_sell_dist', 'review_score', 'review_answer_delay',
#        'product_review_count', 'product_review_mean', 'customer_review_count',
#        'customer_review_mean', 'review_gap', 'seller_sales_count',
#        'seller_revenue', 'mean_seller_product_price',
#        'mean_seller_charm_price', 'product_sales_count', 'product_revenue'],
#       dtype='object')

# %%
# switch to dtype object for further data slicing
for i in ['order_purchase_year',
          'order_purchase_month']:
    data[i] = data[i].astype('object')

# %% [markdown]
# #### Define Raw Categorical & Raw Numercial features

# %%
# raw categorical features
# only '_cat' because levels '_lvl' are redundant with their numerical origin
raw_categorical_features = data.columns[data.columns.str.contains('_cat')]
len(raw_categorical_features)
# Out:
# 7

# %%
# keep a raw cat df
data_raw_categorical = data.filter(raw_categorical_features)

# %%
# raw numerical features
raw_numerical_features = data.select_dtypes(include='number').columns
len(raw_numerical_features)
# Out:
# 42

# %%
# keep a raw cat df
raw_data_numerical = data.filter(raw_numerical_features)

# %%
# Both num and cat features
raw_features_list = list(raw_categorical_features)
raw_features_list.extend(list(raw_numerical_features))
len(raw_features_list)
# Out:
# 49

# %%
# projeter sur un df dédié
raw_data_filtered = data.filter(raw_features_list)
raw_data_filtered.shape
# Out:
# (87086, 49)

# %%
# sample (10%)
raw_data_sample = pd.DataFrame(raw_data_filtered).sample(
    int(data.shape[0]/10),
    random_state=42)
raw_data_sample.shape
# Out:
# (8708, 49)

# %% [markdown]
# # 2. Transform data

# %% [markdown]
# #### define transformer

# %%
# steps transform any feature by type
numerical_pipeline = Pipeline(
    steps=[
        ('rankgauss', QuantileTransformer(n_quantiles=100,
                                          random_state=111,
                                          output_distribution='normal')),
        ('scaler', StandardScaler())
    ]
)
categorical_pipeline = Pipeline(
    steps=[
        ('onehot', OneHotEncoder(handle_unknown='ignore')),
        ('scaler', StandardScaler(with_mean=False))
    ]
)

# %%
# common raw transformer
myrawtransformer = ColumnTransformer(
    transformers=[
        ('cat', categorical_pipeline, raw_categorical_features),
        ('num', numerical_pipeline, raw_numerical_features)])

# %%
len(raw_categorical_features)
# Out:
# 7

# %%
len(raw_numerical_features)
# Out:
# 42

# %% [markdown]
# #### apply transfomer

# %%
# fit transformer
myrawtransformer.fit(raw_data_filtered)
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore')),
#                                                  ('scaler',
#                                                   StandardScaler(with_mean=False))]),
#                                  Index(['purchase_time_zone_cat', 'charmed_price_cat', 'product_cat',
#        'payment_sequence_size_cat', 'payment_installment_size_cat',
#        'main_payment_type_cat', 'seller_main_product_cat'],
#       dtype='object')),
#                                 ('num',...
#        'seller_lat', 'seller_lng', 'order_count', 'customer_lat',
#        'customer_lng', 'cust_sell_dist', 'review_score', 'review_answer_delay',
#        'product_review_count', 'product_review_mean', 'customer_review_count',
#        'customer_review_mean', 'review_gap', 'seller_sales_count',
#        'seller_revenue', 'mean_seller_product_price',
#        'mean_seller_charm_price', 'product_sales_count', 'product_revenue'],
#       dtype='object'))])

# %%
# proceed to get the features names for column headers
encoder = OneHotEncoder()
encoder.fit(data[raw_categorical_features])
raw_categorical_labels = encoder.get_feature_names(raw_categorical_features)

# %%
# rebuild feature's list
raw_columns_names = list(raw_categorical_labels)
raw_columns_names.extend(list(raw_numerical_features))

# %%
# apply columns to the transformed DataFrame
raw_transformed_data = pd.DataFrame(myrawtransformer.transform(raw_data_filtered), columns=raw_columns_names)

# %%
# transformed still contains any data
raw_transformed_data.shape
# Out:
# (87086, 85)

# %% [markdown]
# #### Use case : case of a shortlist

# %%
# shortlist proposal keeping year month for further cuts
features_shortlist = ['cust_sell_dist',
                      'product_price',
                      'product_qlty_index',
                      'product_review_mean',
                      'review_gap',
                      'charmed_price_cat',
                      'purchase_time_zone_cat',
                      'order_purchase_year',
                      'order_purchase_month']

# %%
# for mixed type : shorten and go back to the columns definition
short_data_filtered = data.filter(features_shortlist)

# %%
# num & cat lists
short_categorical_features = short_data_filtered.columns[
    short_data_filtered.columns.str.contains('_cat')]
print(short_categorical_features)
short_numerical_features = short_data_filtered.select_dtypes(
    include='number').columns
print(short_numerical_features)
# Out:
# Index(['charmed_price_cat', 'purchase_time_zone_cat'], dtype='object')
# Index(['cust_sell_dist', 'product_price', 'product_qlty_index',
#        'product_review_mean', 'review_gap'],
#       dtype='object')

# %%
# update transformer
# common short transformer
myshorttransformer = ColumnTransformer(
    transformers=[
        ('cat', categorical_pipeline, short_categorical_features),
        ('num', numerical_pipeline, short_numerical_features)])
myshorttransformer.fit(short_data_filtered)
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore')),
#                                                  ('scaler',
#                                                   StandardScaler(with_mean=False))]),
#                                  Index(['charmed_price_cat', 'purchase_time_zone_cat'], dtype='object')),
#                                 ('num',
#                                  Pipeline(steps=[('rankgauss',
#                                                   QuantileTransformer(n_quantiles=100,
#                                                                       output_distribution='normal',
#                                                                       random_state=111)),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['cust_sell_dist', 'product_price', 'product_qlty_index',
#        'product_review_mean', 'review_gap'],
#       dtype='object'))])

# %%
# proceed to get the features names for column headers
encoder = OneHotEncoder()
encoder.fit(short_data_filtered[short_categorical_features])
short_categorical_labels = encoder.get_feature_names(short_categorical_features)

# %%
# rebuild feature's list
short_columns_names = list(short_categorical_labels)
short_columns_names.extend(list(short_numerical_features))

# %%
# apply columns to the transformed DataFrame
short_transformed_data = pd.DataFrame(myshorttransformer.transform(short_data_filtered), columns=short_columns_names)

# %%
# transformed still contains any data
short_transformed_data.shape
# Out:
# (87086, 12)

# %% [markdown]
# # 3. Reduce data dimension

# %% [markdown]
# #### define PCA reducer

# %%
# target a variance %
n_components = 0.8

# %%
# introduce PCA as dim reducer step into the pipeline
mydimreducer = Pipeline(
    [
        ('pca', PCA(n_components=n_components))
    ])

# %%
# chain transform & reduce
mypreprocessor = Pipeline(
    [
        ('transformer', myrawtransformer),
        ('reducer', mydimreducer)
    ])

# %% [markdown]
# #### apply PCA reducer

# %% [markdown]
# #### PCA to any features (both numerical and categorical)

# %%
# we can go back to entire dataset
raw_data_reduced_df = pd.DataFrame(mypreprocessor.fit_transform(raw_data_filtered))

# %%
# cumulative expl variance ratio
plt.plot(np.array([i for i in range(1, raw_data_reduced_df.shape[1]+1)]),
         np.cumsum(mypreprocessor['reducer']['pca'].explained_variance_ratio_))
plt.title('Cumulative Expl Variance Ratio (up to 80%) \n- Any features -')
# Out:
# Text(0.5, 1.0, 'Cumulative Expl Variance Ratio (up to 80%) \n- Any features -')

# %%
# data projection
plt.scatter(raw_data_reduced_df.iloc[:, 0],
            raw_data_reduced_df.iloc[:, 1],
            alpha=.1)
plt.title('First 2 PCs projection\n- Any features -')
# Out:
# Text(0.5, 1.0, 'First 2 PCs projection\n- Any features -')

# %% [markdown]
# #### PCA to numerical features

# %%
# same for num only
raw_data_numerical_df = pd.DataFrame(
    myrawtransformer.fit_transform(raw_data_filtered),
    columns=raw_columns_names).filter(raw_numerical_features)

# %%
# apply reducer
raw_data_numerical_reduced_df = pd.DataFrame(mypreprocessor['reducer']['pca'].fit_transform(raw_data_numerical_df))

# %%
# cumulative expl variance ratio
plt.plot(np.array([i for i in range(1, raw_data_numerical_reduced_df.shape[1]+1)]),
         np.cumsum(mypreprocessor['reducer']['pca'].explained_variance_ratio_))
plt.title('Cumulative Expl Variance Ratio (up to 80%) \n- Numerical features -')
# Out:
# Text(0.5, 1.0, 'Cumulative Expl Variance Ratio (up to 80%) \n- Numerical features -')
# 2:80: E501 line too long (83 > 79 characters)

# %%
# projection
plt.scatter(raw_data_numerical_reduced_df.iloc[:, 0],
            raw_data_numerical_reduced_df.iloc[:, 1],
            alpha=.1)
plt.title('First 2 PCs projection\n- Numerical features -')
# Out:
# Text(0.5, 1.0, 'First 2 PCs projection\n- Numerical features -')

# %% [markdown]
# #### PCA to categorical features

# %%
# same for catégorical
raw_data_categorical_df = pd.DataFrame(
    myrawtransformer.fit_transform(raw_data_filtered),
    columns=raw_columns_names).filter(list(raw_categorical_labels))

# %%
# reduce
raw_data_categorical_reduced_df = pd.DataFrame(mypreprocessor['reducer']['pca'].fit_transform(raw_data_categorical_df))

# %%
# cumulative expl variance ratio
plt.plot(np.array([i for i in range(1, raw_data_categorical_reduced_df.shape[1]+1)]),
         np.cumsum(mypreprocessor['reducer']['pca'].explained_variance_ratio_))
plt.title('Cumulative Expl Variance Ratio (up to 80%) \n- Categorical features -')
# Out:
# Text(0.5, 1.0, 'Cumulative Expl Variance Ratio (up to 80%) \n- Categorical features -')
# 2:80: E501 line too long (85 > 79 characters)

# %%
plt.scatter(raw_data_categorical_reduced_df.iloc[:, 0],
            raw_data_categorical_reduced_df.iloc[:, 1],
            alpha=.1)
plt.title('First 2 PCs projection\n- Categorical features -')
# Out:
# Text(0.5, 1.0, 'First 2 PCs projection\n- Categorical features -')

# %% [markdown]
# #### use case : PCA to the shortlist

# %%
# chain transform & reduce for short list
myshortpreprocessor = Pipeline(
    [
        ('transformer', myshorttransformer),
        ('reducer', mydimreducer)
    ])

# %%
# PCA has the same set up (with 80 % of explained variance)
myshortpreprocessor['reducer']['pca'].n_components = 0.8

# %%
# apply mydimreducer only
short_transformed_data_reduced_df = pd.DataFrame(myshortpreprocessor['reducer']['pca'].fit_transform(short_transformed_data))

# %%
# cumulative expl variance ratio
plt.plot(np.array([i for i in range(1, short_transformed_data_reduced_df.shape[1]+1)]),
         np.cumsum(mypreprocessor['reducer']['pca'].explained_variance_ratio_))
plt.title('Cumulative Expl Variance Ratio (up to 80%) \n- Shortlisted features -')
# Out:
# Text(0.5, 1.0, 'Cumulative Expl Variance Ratio (up to 80%) \n- Shortlisted features -')
# 2:80: E501 line too long (87 > 79 characters)

# %%
plt.scatter(short_transformed_data_reduced_df.iloc[:, 0],
            short_transformed_data_reduced_df.iloc[:, 1],
            alpha=.1)
plt.title('First 2 PCs projection\n- Shortlisted features -')
# Out:
# Text(0.5, 1.0, 'First 2 PCs projection\n- Shortlisted features -')

# %%
# features contribution to PCs
pca_coordinates = mypreprocessor['reducer']['pca'].components_

# %%
# display feature contributions along principal components
reduced = pd.DataFrame(pca_coordinates)
reduced.columns = short_transformed_data.columns
reduced = pd.melt(reduced.reset_index(), id_vars='index')
reduced.columns = ['x', 'y', 'value']
reduced['x'] = reduced['x'] + 1
heatmap2(
    x=reduced['x'],
    y=reduced['y'],
    size=reduced['value'].abs(),
    color=reduced['value'],
    a=5,
    b=5
)

# %% [markdown]
# # 4. Alternate dimension reducers

# %% [markdown]
# ### 4.1. T-Distributed Stochastic Neighbouring Entities (t-SNE)

# %% [markdown]
# Hyperparameters for t-SNE
# n_jobs number_cpus
# perplexity controls number of nearest-neighbors, use value between 5 and 50
# early_exaggeration=12.0,  For larger values, the space between natural clusters will be larger in the embedded space.
# learning_rate=200.0,  too high or too low: all datapoints will be bunched together.

# %%
# sample (10%) due to complexity case of use case
short_transformed_data_sample = pd.DataFrame(short_transformed_data).sample(
    int(short_transformed_data.shape[0]/10),
    random_state=42)
short_transformed_data_sample.shape
# Out:
# (8708, 12)

# %%
# sample (10%) due to complexity case any features
raw_transformed_data_sample = pd.DataFrame(raw_transformed_data).sample(
    int(short_transformed_data.shape[0]/10),
    random_state=42)
raw_transformed_data_sample.shape
# Out:
# (8708, 85)

# %% [markdown]
# #### t-SNE to any features

# %%
# t-SNE on use case with perplexity tunning
time_start = time.time()
results_list = list()
tsne_results = []
for i in [5, 20, 35, 50, 65, 80]:
    tsne = TSNE(n_components=2, verbose=1, perplexity=i, n_iter=300)
    tsne_results = tsne.fit_transform(raw_transformed_data_sample)
    results_list.append(tsne_results)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.689s...
# [t-SNE] Computed neighbors for 8708 samples in 17.450s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 1.906102
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.167114
# [t-SNE] KL divergence after 300 iterations: 3.867590
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.424s...
# [t-SNE] Computed neighbors for 8708 samples in 18.588s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 2.592688
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.513832
# [t-SNE] KL divergence after 300 iterations: 2.971693
# [t-SNE] Computing 106 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.736s...
# [t-SNE] Computed neighbors for 8708 samples in 21.672s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 2.824874
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.060829
# [t-SNE] KL divergence after 300 iterations: 2.607611
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.857s...
# [t-SNE] Computed neighbors for 8708 samples in 21.305s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 2.973826
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.820267
# [t-SNE] KL divergence after 300 iterations: 2.356912
# [t-SNE] Computing 196 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.362s...
# [t-SNE] Computed neighbors for 8708 samples in 15.737s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 3.085378
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.606651
# [t-SNE] KL divergence after 300 iterations: 2.182162
# [t-SNE] Computing 241 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.395s...
# [t-SNE] Computed neighbors for 8708 samples in 17.891s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 3.176602
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.905174
# [t-SNE] KL divergence after 300 iterations: 2.043798
# t-SNE done! Time elapsed: 297.0262269973755 seconds

# %%
tsne_results_5 = results_list[0]
tsne_results_20 = results_list[1]
tsne_results_35 = results_list[2]
tsne_results_50 = results_list[3]
tsne_results_65 = results_list[4]
tsne_results_80 = results_list[5]

# %%
# display t-SNE results tuning perplexity
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=[15, 5])
ax1.scatter(tsne_results_5[:, 0],
            tsne_results_5[:, 1],
            alpha=.1)
ax1.title.set_text('t-SNE perpl. 5')
ax2.scatter(tsne_results_20[:, 0],
            tsne_results_20[:, 1],
            alpha=.1)
ax2.title.set_text('t-SNE perpl. 20')
ax3.scatter(tsne_results_35[:, 0],
            tsne_results_35[:, 1],
            alpha=.1)
ax3.title.set_text('t-SNE perpl. 35')
plt.show()

# %%
# display t-SNE results tuning perplexity
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=[15, 5])
ax1.scatter(tsne_results_50[:, 0],
            tsne_results_50[:, 1],
            alpha=.1)
ax1.title.set_text('t-SNE perpl. 50')
ax2.scatter(tsne_results_65[:, 0],
            tsne_results_65[:, 1],
            alpha=.1)
ax2.title.set_text('t-SNE perpl. 65')
ax3.scatter(tsne_results_80[:, 0],
            tsne_results_80[:, 1],
            alpha=.1)
ax3.title.set_text('t-SNE perpl. 80')
plt.show()

# %% [markdown]
# #### t-SNE to numerical features

# %%
raw_transformed_numerical_data_sample = raw_transformed_data_sample.filter(raw_numerical_features)

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=300)
tsne_num_results = tsne.fit_transform(raw_transformed_numerical_data_sample)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.129s...
# [t-SNE] Computed neighbors for 8708 samples in 10.058s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 1.960271
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 87.995445
# [t-SNE] KL divergence after 300 iterations: 3.126292
# t-SNE done! Time elapsed: 42.76444220542908 seconds

# %%
plt.scatter(tsne_num_results[:, 0],
            tsne_num_results[:, 1],
            alpha=.1)
plt.title('First 2 T-sne dimensions\n- Numerical features -')
# Out:
# Text(0.5, 1.0, 'First 2 T-sne dimensions\n- Numerical features -')

# %% [markdown]
# #### t-SNE to categorical features

# %%
raw_transformed_categorcial_data_sample = raw_transformed_data_sample.filter(raw_categorical_labels)

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=20, n_iter=300)
tsne_cat_results = tsne.fit_transform(raw_transformed_categorcial_data_sample)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.269s...
# [t-SNE] Computed neighbors for 8708 samples in 5.427s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.688339
# [t-SNE] KL divergence after 300 iterations: 1.745588
# t-SNE done! Time elapsed: 26.723525285720825 seconds

# %%
plt.scatter(tsne_cat_results[:, 0],
            tsne_cat_results[:, 1],
            alpha=.1)
plt.title('First 2 T-sne dimensions\n- Categorical features -')
# Out:
# Text(0.5, 1.0, 'First 2 T-sne dimensions\n- Categorical features -')

# %% [markdown]
# #### t-SNE to features shortlist - Use Case

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=300)
tsne_short_results = tsne.fit_transform(short_transformed_data_sample)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 8708 samples in 0.034s...
# [t-SNE] Computed neighbors for 8708 samples in 1.924s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8708
# [t-SNE] Computed conditional probabilities for sample 2000 / 8708
# [t-SNE] Computed conditional probabilities for sample 3000 / 8708
# [t-SNE] Computed conditional probabilities for sample 4000 / 8708
# [t-SNE] Computed conditional probabilities for sample 5000 / 8708
# [t-SNE] Computed conditional probabilities for sample 6000 / 8708
# [t-SNE] Computed conditional probabilities for sample 7000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8000 / 8708
# [t-SNE] Computed conditional probabilities for sample 8708 / 8708
# [t-SNE] Mean sigma: 0.625118
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.452591
# [t-SNE] KL divergence after 300 iterations: 2.426498
# t-SNE done! Time elapsed: 25.702563285827637 seconds

# %%
plt.scatter(tsne_short_results[:, 0],
            tsne_short_results[:, 1],
            alpha=.1)
plt.title('First 2 T-sne dimensions\n- Use case features -')
# Out:
# Text(0.5, 1.0, 'First 2 T-sne dimensions\n- Use case features -')

# %% [markdown]
# ### 4.2. UMAP

# %% [markdown]
# UMAP's interest reside on its ability to "learn" the manifold structure of the data and preserve that topological structure within fewer dimensional space. <br/>
# UMAP metric can be tuned according to data "type and shape", for instance hamming distance defined to handle binaries and that could better suit to our categorical data. <br/>
# Furthermore UMAP paramters can be tuned according to a clustering perspective. <br/>
# https://umap-learn.readthedocs.io/en/latest/parameters.html#

# %% [markdown]
# n_neighbors balances local (low n_neighbors) vs global structure (high); min_dist minimum distance apart that points are allowed to be in the representation. Use between 0 and 1 ; n_components=2, Number of final dimensions ;    metric="euclidean"  how distance is computed in the ambient space of the input data

# %%
projector_umap = UMAP(random_state=42,
                      n_neighbors=200,
                      min_dist=0.8,
                      n_components=2,
                      metric='manhattan')

# %%
time_start = time.time()
umap_short_results = projector_umap.fit_transform(short_transformed_data_sample)
print('umap done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 2:80: E501 line too long (80 > 79 characters)
# umap done! Time elapsed: 72.81617569923401 seconds

# %%
plt.scatter(umap_short_results[:, 0],
            umap_short_results[:, 1],
            alpha=.1)
plt.title('UMAP 2dim Manhattan 200n 0.8d \n - Use Case -')
# Out:
# Text(0.5, 1.0, 'UMAP 2dim Manhattan 200n 0.8d \n - Use Case -')

# %% [markdown]
# # 5. Cluster data

# %% [markdown]
# ## 5.1. K-Means

# %% [markdown]
# #### define clusterer

# %%
# clustering method step
kmeans_6k = KMeans(n_clusters=6)

# %%
short_transformed_data_reduced_df.shape
# Out:
# (87086, 8)

# %%
# silhouette score comparison with or without PCA
time_start = time.time()
# without PCA : short_transformed_data
kmeans_6k.fit(short_transformed_data)
kmeans_6k_labels = kmeans_6k.labels_
kmeans_6k_silhouette = silhouette_score(short_transformed_data, kmeans_6k_labels)
# with PCA : short_transformed_data_reduced_df
kmeans_6k.fit(short_transformed_data_reduced_df)
kmeans_6k_pca_labels = kmeans_6k.labels_
kmeans_6k_pca_silhouette = silhouette_score(short_transformed_data_reduced_df, kmeans_6k_pca_labels)
print('kmeans 6k with or without pca, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kmeans 6k with or without pca, elapsed time: 331.50557136535645 seconds
# 6:80: E501 line too long (81 > 79 characters)
# 10:80: E501 line too long (100 > 79 characters)

# %%
# results
print('kmeans_6k_silhouette : %f' % kmeans_6k_silhouette)
print('kmeans_6k_pca_silhouette : %f' % kmeans_6k_pca_silhouette)
# Out:
# kmeans_6k_silhouette : 0.257372
# kmeans_6k_pca_silhouette : 0.326331

# %% [markdown]
# we get a better silhouette score after this PCA (80 % expl.variance)

# %%
short_kmeans_6k_pca_results = short_transformed_data_reduced_df.copy()

# %%
short_kmeans_6k_pca_results['clusters'] = kmeans_6k_pca_labels

# %%
short_kmeans_6k_pca_results.columns = ['PC1',
                                       'PC2',
                                       'PC3',
                                       'PC4',
                                       'PC5',
                                       'PC6',
                                       'PC7',
                                       'PC8',
                                       'clusters']
short_kmeans_6k_pca_results['clusters'] = short_kmeans_6k_pca_results['clusters'] + 1

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('Clusters Projection on PCs')

a = sns.scatterplot(ax=axes[0, 0],
                    x='PC1',
                    y='PC2',
                    hue='clusters',
                    palette='Set2',
                    data=short_kmeans_6k_pca_results)
b = sns.scatterplot(ax=axes[0, 1],
                    x='PC3',
                    y='PC4',
                    hue='clusters',
                    palette='Set2',
                    data=short_kmeans_6k_pca_results)
b.legend_.remove()
c = sns.scatterplot(ax=axes[1, 0],
                    x='PC5',
                    y='PC6',
                    hue='clusters',
                    palette='Set2',
                    data=short_kmeans_6k_pca_results)
c.legend_.remove()
d = sns.scatterplot(ax=axes[1, 1],
                    x='PC7',
                    y='PC8',
                    hue='clusters',
                    palette='Set2',
                    data=short_kmeans_6k_pca_results)
d.legend_.remove()

# %%
# clusters size
short_kmeans_6k_pca_results['clusters'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmeans 6k after PCA80 clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmeans 6k after PCA80 clusters size')

# %%
# get back to original data
kmeans_6k_pca_results = data.copy()
kmeans_6k_pca_results['kmeans_clusters'] = kmeans_6k_pca_labels

# %%
kmeans_6k_pca_results['kmeans_clusters'] = kmeans_6k_pca_results['kmeans_clusters'] + 1

# %%
# visualiser les valeurs d'origine par cluster
for i in ['product_price',
          'cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kmeans_clusters',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=kmeans_6k_pca_results,
                height=3,
                aspect=10/5)

# %%
# get back to original data
kmeans_6k_results = data.copy()
kmeans_6k_results['kmeans_clusters'] = kmeans_6k_labels

# %%
kmeans_6k_results['kmeans_clusters'] = kmeans_6k_results['kmeans_clusters'] + 1

# %%
# clusters size
kmeans_6k_results['kmeans_clusters'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmeans 6k no PCA clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmeans 6k no PCA clusters size')

# %%
# visualiser les valeurs d'origine par cluster
for i in ['product_price',
          'cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kmeans_clusters',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=kmeans_6k_results,
                height=3,
                aspect=10/5)

# %% [markdown]
# ## 5.2. Use Case : K-Means with same dim reduction (PCA 80%, 8 PCs)

# %%
short_transformed_data_reduced_df.shape
# Out:
# (87086, 8)

# %%
# empty scores list
kmeans_silhouette_scores = []
kmeans_davies_bouldin_score = []
sse = []

# %%
time_start = time.time()
for n in range(2, 10):
    kmeans = KMeans(n_clusters=n)
    kmeans.fit(short_transformed_data_reduced_df)
    kmeans_labels = kmeans.labels_
    kmeans_inertia = kmeans.inertia_
    kmeans_silhouette = silhouette_score(
        short_transformed_data_reduced_df,
        kmeans_labels)
    kmeans_davies_bouldin = davies_bouldin_score(
        short_transformed_data_reduced_df,
        kmeans_labels)

    # Add metrics to their lists
    kmeans_silhouette_scores.append(kmeans_silhouette)
    kmeans_davies_bouldin_score.append(kmeans_davies_bouldin)
    sse.append(kmeans_inertia)

print('kmeans k scan, silhouette computing, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kmeans k scan, silhouette computing, elapsed time: 1251.3724439144135 seconds

# %%
y = np.array([i for i in range(2, len(kmeans_davies_bouldin_score) + 2)])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.grid(False)
ax2.grid(False)
ax1.plot(y,
         sse,
         'o-',
         markersize=10,
         color='steelblue')
ax2.plot(y,
         kmeans_davies_bouldin_score,
         'v-',
         markersize=10,
         color='red')
ax1.set_xlabel('Nb of clusters')
ax1.set_ylabel('Elbow criterion', color='steelblue')
ax2.set_ylabel('Davies-Bouldin score', color='red')
plt.show()

# %%
kmeans_labels
# Out:
# array([0, 0, 0, ..., 0, 2, 0])

# %% [markdown]
# ## 5.3. K-Means tuning

# %% [markdown]
# #### tuning PCA n_components
# introducing PCA metric explained_variance_ratio

# %%
# empty scores list
# kmeans_npca_silhouette_score = []
kmeans_npca_davies_bouldin_score = []
npca_explained_variance_ratios = []
# kmeans init (6 clusters)
kmeans_npca = KMeans(n_clusters=6)
time_start = time.time()
for n in range(2, short_transformed_data.shape[1]+1):
    # This set the number of PCA components,
    # but leaves other steps unchanged
    myshortpreprocessor['reducer']['pca'].n_components = n
    npca_short_transformed_data_reduced = pd.DataFrame(
        myshortpreprocessor['reducer']['pca'].fit_transform(
            short_transformed_data))
    npca_explained_variance = sum(
        myshortpreprocessor['reducer']['pca'].explained_variance_ratio_)
    kmeans_npca.fit(npca_short_transformed_data_reduced)
    kmeans_npca_labels = kmeans_npca.labels_

    # kmeans_npca_silhouette_score = silhouette_score(
    #    npca_short_transformed_data_reduced,
    #    kmeans_npca_labels)

    kmeans_pca_davies_bouldin = davies_bouldin_score(
        npca_short_transformed_data_reduced,
        kmeans_npca_labels)
    # Add metrics to their lists
    # kmeans_silhouette_scores.append(kmeans_npca_silhouette_score)
    kmeans_npca_davies_bouldin_score.append(kmeans_pca_davies_bouldin)
    npca_explained_variance_ratios.append(npca_explained_variance)
print('npca scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# npca scan, elapsed time: 15.458563804626465 seconds

# %%
y = np.array([i for i in range(2, len(kmeans_npca_davies_bouldin_score) + 2)])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.grid(False)
ax2.grid(False)
ax1.plot(y,
         npca_explained_variance_ratios,
         'o-',
         markersize=10,
         color='steelblue')
ax2.plot(y,
         kmeans_npca_davies_bouldin_score,
         'v-',
         markersize=10,
         color='red')
ax1.set_xlabel('Nb of Pincipal Components')
ax1.set_ylabel('Sum of PCA Explaine variance', color='steelblue')
ax2.set_ylabel('Davies-Bouldin score', color='red')
plt.show()

# %% [markdown]
# ### nested loops to parse npca components and nclust clusters

# %%
# empty results
results = []
# kmeans_nested_silhouette_score = []
kmeans_nested_davies_bouldin_score = []
npca_nested_explained_variance_ratios = []
time_start = time.time()
for npca in range(2, short_transformed_data.shape[1]+1):
    # This set the number of PCA Components,
    myshortpreprocessor['reducer']['pca'].n_components = npca
    nested_short_transformed_data_reduced = pd.DataFrame(
        myshortpreprocessor['reducer']['pca'].fit_transform(
            short_transformed_data))
    npca_nested_explained_variance = sum(
        myshortpreprocessor['reducer']['pca'].explained_variance_ratio_)
    for nclust in range(2, 10):
        kmeans_nclust = KMeans(n_clusters=nclust)
        kmeans_nclust.fit(nested_short_transformed_data_reduced)
        kmeans_nclust_labels = kmeans_nclust.labels_
        # kmeans_nested_silhouette_score = silhouette_score(
        #    nested_short_transformed_data_reduced,
        #    kmeans_nclust_labels)
        kmeans_nested_davies_bouldin_score = davies_bouldin_score(
            nested_short_transformed_data_reduced,
            kmeans_nclust_labels)
        # Add metrics to their lists
        results.append({'npca': npca,
                        'nclust': nclust,
                         # 'kmeans_silhouette_score': kmeans_nested_silhouette_score,
                        'kmeans_davies_bouldin': kmeans_nested_davies_bouldin_score})
print('nested npca nclust scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# nested npca nclust scan, elapsed time: 112.35232138633728 seconds
# 28:26: E127 continuation line over-indented for visual indent
# 28:80: E501 line too long (85 > 79 characters)
# 29:80: E501 line too long (85 > 79 characters)

# %%
df = pd.DataFrame(results)
print(df.iloc[df['kmeans_davies_bouldin'].idxmin()])
# Out:
# npca                     2.000000
# nclust                   6.000000
# kmeans_davies_bouldin    0.133328
# Name: 4, dtype: float64

# %%
# get to 2 PCs pca to confirm how kmeans behave
myshortpreprocessor['reducer']['pca'].n_components = 2
pc2_short_data_reduced = pd.DataFrame(
    myshortpreprocessor['reducer']['pca'].fit_transform(
        short_transformed_data))
kmeans_6k_2pc = KMeans(n_clusters=6)
kmeans_6k_2pc.fit(pc2_short_data_reduced)
kmeans_6k_2pc_labels = kmeans_6k_2pc.labels_
kmeans_6k_2pc_silhouette = silhouette_score(
    pc2_short_data_reduced,
    kmeans_6k_2pc_labels)
print('kmeans_6k_2pc_silhouette : %f' % kmeans_6k_2pc_silhouette)
# Out:
# kmeans_6k_2pc_silhouette : 0.904481

# %%
# prepare plotting results
kmeans_6k_2pc_results = pc2_short_data_reduced.copy()
kmeans_6k_2pc_results['clusters'] = kmeans_6k_2pc_labels
kmeans_6k_2pc_results['clusters'] = kmeans_6k_2pc_results['clusters'] + 1
kmeans_6k_2pc_results.columns = ['PC1',
                                 'PC2',
                                 'clusters']

# %%
# 6 clusters for pca 2 components
fig.suptitle('6 Clusters Projection on PCA 2 components')
sns.scatterplot(x='PC1',
                y='PC2',
                hue='clusters',
                palette='Set2',
                data=kmeans_6k_2pc_results)

# %%
# visualize clusters
kmeans_6k_2pc = data.copy()

# %%
kmeans_6k_2pc['kmeans_cluster'] = kmeans_6k_2pc_labels
kmeans_6k_2pc_results['clusters'] = kmeans_6k_2pc_results['clusters'] + 1

# %%
# clusters size
kmeans_6k_2pc['kmeans_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmeans 6k after PC2 clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmeans 6k after PC2 clusters size')

# %%
sns.catplot(x='kmeans_cluster',
            y='product_price',
            kind='violin',
            inner='box',
            palette='Set2',
            data=kmeans_6k_2pc[kmeans_6k_2pc['product_price'] <= 400],
            height=3,
            aspect=10/5)

# %%
# visualiser les valeurs d'origine par cluster
for i in ['cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kmeans_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=kmeans_6k_2pc,
                height=3,
                aspect=10/5)

# %%
# Stacked barplot
charmed_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['charmed_price_cat'] == 'Charmed_Price',
    :]['kmeans_cluster'].value_counts()/kmeans_6k_2pc.shape[0]
uncharmed_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['charmed_price_cat'] != 'Charmed_Price',
    :]['kmeans_cluster'].value_counts()/kmeans_6k_2pc.shape[0]
df_charm = pd.DataFrame([charmed_ratio, uncharmed_ratio])
df_charm.index = ['PriceCharmed', 'Not_PriceCharmed']

# Plot
df_charm.plot(kind='barh',
              stacked=True,
              color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3',
                     '#a6d854', '#ffd92f'],
              title='"Charm Price" effect accross clusters')
plt.xlabel('stacked Cluster ratio within Charm Price category')
plt.legend(title='kmeans cluster')

# %%
# Stacked barplot
PM_WD_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['purchase_time_zone_cat'] == 'PM-WD',
    :]['kmeans_cluster'].value_counts()/data.shape[0]
Evening_WD_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['purchase_time_zone_cat'] == 'Evening-WD',
    :]['kmeans_cluster'].value_counts()/data.shape[0]
WE_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['purchase_time_zone_cat'] == 'WE',
    :]['kmeans_cluster'].value_counts()/data.shape[0]
AM_WD_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['purchase_time_zone_cat'] == 'AM-WD',
    :]['kmeans_cluster'].value_counts()/data.shape[0]
Night_ratio = kmeans_6k_2pc.loc[
    kmeans_6k_2pc['purchase_time_zone_cat'] == 'Night',
    :]['kmeans_cluster'].value_counts()/data.shape[0]
df_zone = pd.DataFrame([PM_WD_ratio,
                        Evening_WD_ratio,
                        WE_ratio,
                        AM_WD_ratio,
                        Night_ratio])
df_zone.index = ['PM-WD', 'Evening-WD', 'WE', 'AM-WD', 'Night']

# Plot
df_zone.plot(kind='barh',
             stacked=True,
             color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
             title='Purchase Time Zone accross clusters')
plt.xlim([0, 0.31])
plt.xlabel('stacked Cluster ratio within each Purchase Time Zone')
plt.legend(title='kmeans cluster')

# %% [markdown]
# ## 5.4. K-Means : evaluation of alternate reducer t-SNE

# %%
# get back tsne_short_sample
tsne_short_sample = pd.DataFrame(tsne_short_results)
tsne_short_sample.shape

# %%
# empty scores list
# kmeans_tsen_silhouette_scores = []
kmeans_tsne_davies_bouldin_score = []
sse_tsne = []
time_start = time.time()
for n in range(2, 10):
    kmeans_tsne = KMeans(n_clusters=n)
    kmeans_tsne.fit(tsne_short_sample)
    kmeans_tsne_labels = kmeans_tsne.labels_
    kmeans_tsne_inertia = kmeans_tsne.inertia_
    # kmeans_silhouette = silhouette_score(tsne_short_sample, kmeans_labels)
    kmeans_tnse_davies_bouldin = davies_bouldin_score(
        tsne_short_sample,
        kmeans_tsne_labels)
    # Add metrics to their lists
    # kmeans_silhouette_scores.append(kmeans_silhouette)
    kmeans_tsne_davies_bouldin_score.append(kmeans_tnse_davies_bouldin)
    sse_tsne.append(kmeans_tsne_inertia)

print('kmeans k scan, with tsne 2 components, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kmeans k scan, with tsne 2 components, elapsed time: 2.2779974937438965 seconds

# %%
y = np.array([i for i in range(2, len(kmeans_tsne_davies_bouldin_score) + 2)])
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.grid(False)
ax2.grid(False)
ax1.plot(y,
         sse_tsne,
         'o-',
         markersize=10,
         color='steelblue')
ax2.plot(y,
         kmeans_tsne_davies_bouldin_score,
         'v-',
         markersize=10,
         color='red')
ax1.set_xlabel('Nb of clusters')
ax1.set_ylabel('Elbow criterion', color='steelblue')
ax2.set_ylabel('Davies-Bouldin score', color='red')
plt.show()

# %%
# silhouette score comparison with or without tsne
kmeans_4k = KMeans(n_clusters=4)
time_start = time.time()
# without tsne : short_transformed_data_sample
kmeans_4k.fit(short_transformed_data_sample)
kmeans_4k_labels = kmeans_4k.labels_
kmeans_4k_silhouette = silhouette_score(
    short_transformed_data_sample,
    kmeans_4k_labels)
# with tsne : tsne_short_sample
kmeans_4k.fit(tsne_short_sample)
kmeans_4k_tsne_labels = kmeans_4k.labels_
kmeans_4k_tsne_silhouette = silhouette_score(
    tsne_short_sample,
    kmeans_4k_tsne_labels)
print('kmeans 4k with or without tsne, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kmeans 4k with or without tsne, elapsed time: 3.8633716106414795 seconds

# %%
# results
print('kmeans_4k_silhouette : %f' % kmeans_4k_silhouette)
print('kmeans_4k_tsne_silhouette : %f' % kmeans_4k_tsne_silhouette)
# Out:
# kmeans_4k_silhouette : 0.241963
# kmeans_4k_tsne_silhouette : 0.376905

# %%
# prepare plotting results
tsne_kmeans_4k_results = tsne_short_sample.copy()
tsne_kmeans_4k_results['clusters'] = kmeans_4k_tsne_labels
tsne_kmeans_4k_results['clusters'] = tsne_kmeans_4k_results['clusters'] + 1
tsne_kmeans_4k_results.columns = ['tsne 2d-one',
                                  'tsne 2d-two',
                                  'clusters']

# %%
# 4 clusters for tsne
fig.suptitle('Clusters Projection on tsne 2d')
sns.scatterplot(x='tsne 2d-one',
                y='tsne 2d-two',
                hue='clusters',
                palette='Set2',
                data=tsne_kmeans_4k_results)

# %%
sample_tsne = short_transformed_data_sample.reset_index()

# %%
sample_tsne['kmeans_4k_cluster'] = tsne_kmeans_4k_results['clusters']

# %%
# clusters size
sample_tsne['kmeans_4k_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmeans 4k after tsne clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmeans 4k after tsne clusters size')

# %%
sns.catplot(x='kmeans_4k_cluster',
            y='product_price',
            kind='violin',
            inner='box',
            palette='Set2',
            data=sample_tsne[sample_tsne['product_price'] <= 400],
            height=3,
            aspect=10/5)

# %%
# visualiser les valeurs d'origine par cluster
for i in ['cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kmeans_4k_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=sample_tsne,
                height=3,
                aspect=10/5)

# %%
# get to 9 clusters to see how kmeans behave
kmeans_9k = KMeans(n_clusters=9)
kmeans_9k.fit(tsne_short_sample)
kmeans_9k_tsne_labels = kmeans_9k.labels_
kmeans_9k_tsne_silhouette = silhouette_score(
    tsne_short_sample,
    kmeans_9k_tsne_labels)
print('kmeans_9k_tsne_silhouette : %f' % kmeans_9k_tsne_silhouette)
# Out:
# kmeans_9k_tsne_silhouette : 0.404643

# %%
# prepare plotting results
tsne_kmeans_9k_results = tsne_short_sample.copy()
tsne_kmeans_9k_results['clusters'] = kmeans_9k_tsne_labels
tsne_kmeans_9k_results['clusters'] = tsne_kmeans_9k_results['clusters'] + 1
tsne_kmeans_9k_results.columns = ['tsne 2d-one',
                                  'tsne 2d-two',
                                  'clusters']

# %%
# 9 clusters for tsne
fig.suptitle('Clusters Projection on tsne 2d - 9 clusters')
sns.scatterplot(x='tsne 2d-one',
                y='tsne 2d-two',
                hue='clusters',
                palette='Set2',
                data=tsne_kmeans_9k_results)

# %%
sample_tsne = short_transformed_data_sample.reset_index()

# %%
sample_tsne['kmeans_9k_cluster'] = tsne_kmeans_9k_results['clusters']

# %%
sample_tsne = sample_tsne.sort_values('kmeans_9k_cluster', ascending=True)

# %%
# clusters size
sample_tsne['kmeans_9k_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#b3b3b3', '#66c2a5', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3',
           '#a6d854', '#ffd92f', '#e5c494'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmeans 9k after tsne clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmeans 9k after tsne clusters size')

# %%
# visualiser les valeurs d'origine par cluster
for i in ['product_price',
          'cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kmeans_9k_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=sample_tsne,
                height=3,
                aspect=10/5)

# %% [markdown]
# Altough we should go back to original values, we see that product_price is not discriminating, qlty_index and distance are poor, and both reviews are the most discriminating.

# %% [markdown]
# # 6. Alternate clusterers

# %% [markdown]
# ## 6.1. HDBSCAN
# https://hdbscan.readthedocs.io/

# %% [markdown]
# #### HDBSCAN after PCA 80%

# %%
# get back to pca data
short_transformed_data_reduced_df.shape
# Out:
# (87086, 8)

# %%
# sample
pca_short_sample = pd.DataFrame(short_transformed_data_reduced_df).sample(
    int(short_transformed_data_reduced_df.shape[0]/10),
    random_state=42)
pca_short_sample.shape
# Out:
# (8708, 8)

# %%
# initiate dbscan
dbscan = DBSCAN(eps=1.7, min_samples=10, metric='manhattan')

# %%
# perform clustering
dbscan.fit(pca_short_sample)
dbscan_labels = dbscan.labels_
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_noise_ = list(dbscan_labels).count(-1)
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# compute silhouette score
dbscan_labels_silhouette = silhouette_score(
    pca_short_sample,
    dbscan_labels)
print('dbscan_labels_silhouette : %f' % dbscan_labels_silhouette)
# Out:
# Estimated number of clusters: 10
# Estimated number of noise points: 143
# dbscan_labels_silhouette : 0.399960

# %%
# prepare plotting results
dbscan_results = pca_short_sample.copy()
dbscan_results['clusters'] = dbscan_labels

# %%
# remove noise points
dbscan_results = dbscan_results[dbscan_results['clusters'] != -1]

# %%
# rename columns
dbscan_results.columns = ['PC1',
                          'PC2',
                          'PC3',
                          'PC4',
                          'PC5',
                          'PC6',
                          'PC7',
                          'PC8',
                          'clusters']

# %%
# start from cluster 1
dbscan_results['clusters'] = dbscan_results['clusters'] + 1

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('Clusters Projection on PCs')

a = sns.scatterplot(ax=axes[0, 0],
                    x='PC1',
                    y='PC2',
                    hue='clusters',
                    palette='Set2',
                    data=dbscan_results)
b = sns.scatterplot(ax=axes[0, 1],
                    x='PC3',
                    y='PC4',
                    hue='clusters',
                    palette='Set2',
                    data=dbscan_results)
b.legend_.remove()
c = sns.scatterplot(ax=axes[1, 0],
                    x='PC5',
                    y='PC6',
                    hue='clusters',
                    palette='Set2',
                    data=dbscan_results)
c.legend_.remove()
d = sns.scatterplot(ax=axes[1, 1],
                    x='PC7',
                    y='PC8',
                    hue='clusters',
                    palette='Set2',
                    data=dbscan_results)
d.legend_.remove()

# %%
# get back to the transformed sample
sample_dbscan = short_transformed_data_sample.copy()
sample_dbscan['clusters'] = dbscan_labels
# remove noise points
sample_dbscan = sample_dbscan[sample_dbscan['clusters'] != -1]
# start from cluster 1
sample_dbscan['clusters'] = sample_dbscan['clusters'] + 1

# %%
# clusters size
sample_dbscan['clusters'].value_counts().plot(
    kind='barh',
    color=['#66c2a5', '#e5c494', '#8da0cb', '#e78ac3',
           '#a6d854', '#66c2a5', '#b3b3b3', '#fc8d62',
           '#ffd92f', '#fc8d62'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('hdbscan pca 80%s clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'hdbscan pca 80%s clusters size')

# %%
# visualiser les valeurs d'origine par cluster
for i in ['product_price',
          'cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='clusters',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=sample_dbscan,
                height=3,
                aspect=10/5)

# %% [markdown]
# #### HDBSCAN after PCA 2 PCs

# %%
pc2_short_data_reduced.shape
# Out:
# (87086, 2)

# %%
# sample (10%)
pc2_short_data_sample = pd.DataFrame(pc2_short_data_reduced).sample(
    int(pc2_short_data_reduced.shape[0]/10),
    random_state=42)
pc2_short_data_sample.shape
# Out:
# (8708, 2)

# %%
# perform clustering
dbscan.fit(pc2_short_data_sample)
dbscan_pc2_labels = dbscan.labels_
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(dbscan_pc2_labels)) - (1 if -1 in dbscan_pc2_labels else 0)
n_noise_ = list(dbscan_pc2_labels).count(-1)
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# compute silhouette score
dbscan_pc2_labels_silhouette = silhouette_score(
    pc2_short_data_sample,
    dbscan_pc2_labels)
print('dbscan_pc2_labels_silhouette : %f' % dbscan_pc2_labels_silhouette)
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 0
# 5:80: E501 line too long (81 > 79 characters)
# dbscan_pc2_labels_silhouette : 0.634935

# %%
# prepare plotting results
dbscan_pc2_results = pc2_short_data_sample.copy()
dbscan_pc2_results['clusters'] = dbscan_pc2_labels

# %%
# remove noise points
dbscan_pc2_results = dbscan_pc2_results[dbscan_pc2_results['clusters'] != -1]

# %%
# rename columns
dbscan_pc2_results.columns = ['PC1',
                              'PC2',
                              'clusters']

# %%
# start from cluster 1
dbscan_pc2_results['clusters'] = dbscan_pc2_results['clusters'] + 1

# %%
# 2 clusters with HDBSCAN for tsne
fig.suptitle('HDBSCAN Clusters Projection on pca 2 PCs - 2 clusters')
sns.scatterplot(x='PC1',
                y='PC2',
                hue='clusters',
                palette='Set2',
                data=dbscan_pc2_results)

# %%
# clusters size
dbscan_pc2_results['clusters'].value_counts().plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('hdbscan pca 2PCs clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'hdbscan pca 2PCs clusters size')

# %% [markdown]
# #### HDBSCAN after t-SNE 2d transformation

# %%
tsne_short_sample.shape
# Out:
# (8708, 2)

# %%
# perform clustering
dbscan.fit(tsne_short_sample)
dbscan_tsne_labels = dbscan.labels_
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(dbscan_tsne_labels)) - (1 if -1 in dbscan_tsne_labels else 0)
n_noise_ = list(dbscan_tsne_labels).count(-1)
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# compute silhouette score
dbscan_tsne_labels_silhouette = silhouette_score(
    tsne_short_sample,
    dbscan_tsne_labels)
print('dbscan_tsne_labels_silhouette : %f' % dbscan_tsne_labels_silhouette)
# Out:
# Estimated number of clusters: 11
# Estimated number of noise points: 0
# 5:80: E501 line too long (83 > 79 characters)
# dbscan_tsne_labels_silhouette : 0.006387

# %%
# prepare plotting results
dbscan_tsne_results = tsne_short_sample.copy()
dbscan_tsne_results['clusters'] = dbscan_tsne_labels

# %%
# remove noise points
dbscan_tsne_results = dbscan_tsne_results[dbscan_tsne_results['clusters'] != -1]

# %%
# rename columns
dbscan_tsne_results.columns = ['tsne-2d one',
                               'tsne-2d two',
                               'clusters']

# %%
# start from cluster 1
dbscan_tsne_results['clusters'] = dbscan_tsne_results['clusters'] + 1

# %%
# 11 clusters with HDBSCAN for tsne
fig.suptitle('HDBSCAN Clusters Projection on tsne 2d - 11 clusters')
sns.scatterplot(x='tsne-2d one',
                y='tsne-2d two',
                hue='clusters',
                palette='Set2',
                data=dbscan_tsne_results)

# %%
# clusters size
dbscan_tsne_results['clusters'].value_counts().plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3',
           '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3',
           '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('hdbscan tsne clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'hdbscan tsne clusters size')

# %% [markdown]
# #### HDBSCAN after no transformation

# %%
short_transformed_data_sample.shape
# Out:
# (8708, 12)

# %%
# perform clustering
dbscan.fit(short_transformed_data_sample)
dbscan_raw_labels = dbscan.labels_
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(dbscan_raw_labels)) - (1 if -1 in dbscan_raw_labels else 0)
n_noise_ = list(dbscan_raw_labels).count(-1)
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# compute silhouette score
dbscan_raw_labels_silhouette = silhouette_score(
    short_transformed_data_sample,
    dbscan_raw_labels)
print('dbscan_raw_labels_silhouette : %f' % dbscan_raw_labels_silhouette)
# Out:
# Estimated number of clusters: 20
# Estimated number of noise points: 1765
# 5:80: E501 line too long (81 > 79 characters)
# dbscan_raw_labels_silhouette : 0.130021

# %% [markdown]
# # 7. Enhance Actionability through K-Modes

# %% [markdown]
# k-Modes intend to extend the k-Means algorithm, dedicated to categorical features : with discrete data as input (even with labels), it performs clustering that minimize a cost-function that measures a "matching dissimilarity". A cost unit is spent on any category switch. <br/>
#
# Pros :
# - raw data (unpreprocessed) can be considered as inputs (even labels),
# - it provides a clear cluster description, based on centroïd values,
# - among the various init techniques (with pretty high dependency to init), 'Cao' research offers a deterministic approach introducing density of the data to their Modes (i.e. most frequent values). <br/>
#
# Cons :
# this depends on the feature discretization in the first place, with <br/>
# - cost approximation is wrong for ordinal features, i.e. cost is the same for any switch, even when passing from below_median to over_median (e.g. 1 to 3).
# - while trying to find the best "k", the algorithm may reward the features with a 'k' corresponding discretization : e.g. the 5 levels of review scores would obviously lead to split into 5 clusters.<br/>

# %% [markdown]
# more details :
# - https://www.sciencedirect.com/science/article/pii/S1319157818300065 <br/>
# - https://medium.com/@davidmasse8/unsupervised-learning-for-categorical-data-dd7e497033ae <br/>

# %% [markdown]
# ## 7.1. Build a rough segmentation

# %%
# primary use case : get lvl & cat based on features_shortlist
features_shortlist
# Out:
# ['cust_sell_dist',
#  'product_price',
#  'product_qlty_index',
#  'product_review_mean',
#  'review_gap',
#  'charmed_price_cat',
#  'purchase_time_zone_cat',
#  'order_purchase_year',
#  'order_purchase_month']

# %%
# features candidates for K-Modes : lvl & cat
print(data.columns[data.columns.str.contains('_lvl')])
print(data.columns[data.columns.str.contains('_cat')])
# Out:
# Index(['delivery_vs_estimated_lvl', 'freight_percentage_lvl',
#        'product_qlty_index_lvl', 'payment_lvl', 'product_price_lvl',
#        'cust_sell_dist_lvl', 'review_answer_delay_lvl',
#        'product_review_mean_lvl', 'review_gap_lvl'],
#       dtype='object')
# Index(['purchase_time_zone_cat', 'charmed_price_cat', 'product_cat',
#        'payment_sequence_size_cat', 'payment_installment_size_cat',
#        'main_payment_type_cat', 'seller_main_product_cat'],
#       dtype='object')

# %%
# shortlist lvl mapping (no need of month, year)
kmodes_shortlist = ['cust_sell_dist_lvl',
                    'product_price_lvl',
                    'product_qlty_index_lvl',
                    'product_review_mean_lvl',
                    'review_gap_lvl',
                    'charmed_price_cat',
                    'purchase_time_zone_cat']

# %%
data_kmodes = data.filter(kmodes_shortlist)
data_kmodes.shape
# Out:
# (87086, 7)

# %%
# get the data 'mode' with mono cluster : n_clusters = 1
# 'Cao' deterministic init computing feature modes
n_clusters = 1
km_test = KModes(n_clusters=n_clusters, init='Cao', n_init=1, verbose=1)
km_test.fit_predict(data_kmodes)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 331681.0
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint16)

# %%
# centroids values
km_test.cluster_centroids_
# Out:
# array([['Near_Dist', 'Light_Price', 'High_QltyIdx', 'Low_Score',
#         'Better_Review', 'Charmed_Price', 'PM-WD']], dtype='<U13')

# %%
mask = (data_kmodes['cust_sell_dist_lvl'] == 'Near_Dist') &\
    (data_kmodes['product_price_lvl'] == 'Light_Price') &\
    (data_kmodes['product_qlty_index_lvl'] == 'High_QltyIdx') &\
    (data_kmodes['product_review_mean_lvl'] == 'Low_Score') &\
    (data_kmodes['review_gap_lvl'] == 'Better_Review') &\
    (data_kmodes['charmed_price_cat'] == 'Charmed_Price') &\
    (data_kmodes['purchase_time_zone_cat'] == 'PM-WD')

# %%
print(data_kmodes[mask].shape)
# Out:
# (277, 7)

# %%
# cost as a function of n_clusters
time_start = time.time()
results_scan = []
for n_clusters in range(1, 10):
    kmode_scan = KModes(n_clusters=n_clusters, init="Cao", n_init=1, verbose=1)
    kmode_scan.fit_predict(data_kmodes)
    results_scan.append(kmode_scan.cost_)
print('kmodes k scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 331681.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 277108.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 249245.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 231980.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 224446.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 217536.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 210143.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2479, cost: 203280.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2449, cost: 196413.0
# kmodes k scan, elapsed time: 104.07845854759216 seconds

# %%
# costs decrease
y = np.array([i for i in range(1, 10)])
plt.plot(y, results_scan)
plt.title('cost values by clusters nb')
# Out:
# Text(0.5, 1.0, 'cost values by clusters nb')

# %%
# let's see of what are made the 4 clusters
time_start = time.time()
n_clusters = 4
km_test = KModes(n_clusters=n_clusters, init='Cao', n_init=1, verbose=1)
km_test.fit_predict(data_kmodes)
print('kmodes single computation, elapsed time: {} seconds'.format(time.time()-time_start))
# centroids values
km_test.cluster_centroids_
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 231980.0
# kmodes single computation, elapsed time: 10.422129392623901 seconds
# array([['Near_Dist', 'Light_Price', 'High_QltyIdx', 'Low_Score',
#         'Better_Review', 'Charmed_Price', 'PM-WD'],
#        ['Far_Dist', 'Medium_Price', 'Low_QltyIdx', 'Top_Score',
#         'Same_Review', 'Charmed_Price', 'Evening-WD'],
#        ['AroundMed_Dist', 'Light_Price', 'Low_QltyIdx', 'Medium_Score',
#         'Worst_Review', 'Uncharmed_Price', 'AM-WD'],
#        ['Far_Dist', 'Light_Price', 'Low_QltyIdx', 'Medium_Score',
#         'Better_Review', 'Charmed_Price', 'WE']], dtype='<U15')
# 6:80: E501 line too long (91 > 79 characters)

# %% [markdown]
# ## 7.2. K-Modes visualization

# %%
# cluster balance & contents
data['kmodes_cluster'] = km_test.labels_

# %% [raw]
# len(data['kmodes_cluster'].unique())

# %%
# clusters size
data['kmodes_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kmodes clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kmodes clusters size')

# %%
sns.catplot(x='kmodes_cluster',
            y='product_price',
            kind='violin',
            inner='box',
            palette='Set2',
            data=data[data['product_price'] <= 400],
            height=3,
            aspect=10/5)

# %%
# original features
cluster_features_display = ['cust_sell_dist',
                            'product_qlty_index',
                            'product_review_mean',
                            'review_gap']

# %%
# visualiser les valeurs d'origine par cluster
for i in cluster_features_display:
    sns.catplot(x='kmodes_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=data,
                height=3,
                aspect=10/5)

# %%
# Stacked barplot
charmed_ratio = data.loc[
    data['charmed_price_cat'] == 'Charmed_Price',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
uncharmed_ratio = data.loc[
    data['charmed_price_cat'] != 'Charmed_Price',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
df_charm = pd.DataFrame([charmed_ratio, uncharmed_ratio])
df_charm.index = ['PriceCharmed', 'Not_PriceCharmed']

# Plot
df_charm.plot(kind='barh',
              stacked=True,
              color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
              title='"Charm Price" effect accross clusters')
plt.xlabel('stacked Cluster ratio within Charm Price category')
plt.legend(title='kmodes_cluster')

# %%
# Stacked barplot
PM_WD_ratio = data.loc[
    data['purchase_time_zone_cat'] == 'PM-WD',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
Evening_WD_ratio = data.loc[
    data['purchase_time_zone_cat'] == 'Evening-WD',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
WE_ratio = data.loc[
    data['purchase_time_zone_cat'] == 'WE',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
AM_WD_ratio = data.loc[
    data['purchase_time_zone_cat'] == 'AM-WD',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
Night_ratio = data.loc[
    data['purchase_time_zone_cat'] == 'Night',
    :]['kmodes_cluster'].value_counts()/data.shape[0]
df_zone = pd.DataFrame([PM_WD_ratio,
                        Evening_WD_ratio,
                        WE_ratio,
                        AM_WD_ratio,
                        Night_ratio])
df_zone.index = ['PM-WD', 'Evening-WD', 'WE', 'AM-WD', 'Night']

# Plot
df_zone.plot(kind='barh',
             stacked=True,
             color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
             title='Purchase Time Zone accross clusters')
plt.xlim([0, 0.31])
plt.xlabel('stacked Cluster ratio within each Purchase Time Zone')
plt.legend(title='kmodes_cluster')

# %%
# affichier la nouvelle répartion (carte)
fig, ax = plt.subplots(figsize=(10, 10))
sns.scatterplot(x='customer_lng',
                y='customer_lat',
                data=data,
                palette='Set2',
                hue='kmodes_cluster')
sns.scatterplot(x='seller_lng',
                y='seller_lat',
                color='grey',
                data=data,
                label='Sellers')
plt.title('Customers locations by cluster')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# mean sale price by clusters
df_sales_clusters = data.groupby(
    'kmodes_cluster',
    as_index=False).agg({'total_price': ['mean']})
df_sales_clusters.columns = ['kmodes_cluster',
                             'mean_price']

sns.barplot(y='kmodes_cluster',
            x='mean_price',
            data=df_sales_clusters,
            orient='h',
            palette='Set2').set_title('Mean Price by Cluster')
# Out:
# Text(0.5, 1.0, 'Mean Price by Cluster')

# %%
# répartition des ventes par catégorie de produit
df_sales_clust_categ = data.groupby(
    ['product_cat', 'kmodes_cluster'],
    as_index=False).agg({'order_id': ['count']})
df_sales_clust_categ.columns = ['product_cat',
                                'kmodes_cluster',
                                'count']
fig, ax = plt.subplots(figsize=(5, 10))
ax = sns.barplot(y='product_cat',
                 x='count',
                 hue='kmodes_cluster',
                 palette='Set2',
                 data=df_sales_clust_categ)
ax.set(xlabel='Sales Revenue',
       ylabel='Products Categories',
       title='Sales by Category for each Cluster')
# Out:
# [Text(0, 0.5, 'Products Categories'),
#  Text(0.5, 0, 'Sales Revenue'),
#  Text(0.5, 1.0, 'Sales by Category for each Cluster')]

# %% [markdown]
# ## 7.3. Assess K-Modes stability : by comparison to "rising" (2017 - baseline)

# %% [markdown]
# How different would be the clusters consider the two periods 2017 rise and 2018 stable?

# %%
data_rise = data[data['order_purchase_year'] == 2017]
data_rise_kmodes = data_rise.filter(kmodes_shortlist)
data_rise_kmodes.shape
# Out:
# (38731, 7)

# %%
data_stable = data[data['order_purchase_year'] == 2018]
data_stable_kmodes = data_stable.filter(kmodes_shortlist)
data_stable_kmodes.shape
# Out:
# (48352, 7)

# %%
# km_test init
n_clusters = 4
km_test = KModes(n_clusters=n_clusters, init='Cao', n_init=1, verbose=1)

# %%
# let's see of what are made the 4 clusters
time_start = time.time()
km_test.fit_predict(data_rise_kmodes)
print('kmodes two computation, elapsed time: {} seconds'.format(time.time()-time_start))
# centroids values
print(km_test.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 106439.0
# 4:80: E501 line too long (88 > 79 characters)
# kmodes two computation, elapsed time: 5.187240123748779 seconds
# [['Far_Dist' 'Light_Price' 'High_QltyIdx' 'Low_Score' 'Better_Review'
#   'Charmed_Price' 'Evening-WD']
#  ['AroundMed_Dist' 'Medium_Price' 'Low_QltyIdx' 'Medium_Score'
#   'Same_Review' 'Charmed_Price' 'PM-WD']
#  ['Near_Dist' 'Light_Price' 'Low_QltyIdx' 'Top_Score' 'Worst_Review'
#   'Uncharmed_Price' 'WE']
#  ['AroundMed_Dist' 'Light_Price' 'Low_QltyIdx' 'Top_Score'
#   'Better_Review' 'Charmed_Price' 'AM-WD']]

# %%
# let's see of what are made the 4 clusters
time_start = time.time()
km_test.fit_predict(data_stable_kmodes)
print('kmodes two computation, elapsed time: {} seconds'.format(time.time()-time_start))
# centroids values
print(km_test.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 130819.0
# 4:80: E501 line too long (88 > 79 characters)
# kmodes two computation, elapsed time: 5.93228816986084 seconds
# [['Near_Dist' 'Light_Price' 'Low_QltyIdx' 'Top_Score' 'Better_Review'
#   'Charmed_Price' 'PM-WD']
#  ['AroundMed_Dist' 'Medium_Price' 'High_QltyIdx' 'Low_Score'
#   'Same_Review' 'Uncharmed_Price' 'Evening-WD']
#  ['Far_Dist' 'Light_Price' 'High_QltyIdx' 'Medium_Score' 'Worst_Review'
#   'Charmed_Price' 'Evening-WD']
#  ['AroundMed_Dist' 'Light_Price' 'High_QltyIdx' 'Low_Score'
#   'Better_Review' 'Charmed_Price' 'AM-WD']]

# %% [markdown]
# As a result, with lead 'Medium Priced' centroïd for our most actionnable segment, K-Modes split 2017 & 2018 could not find the same consistency. <br/>
# Stability on such big period is pretty bad, with only 2 segments not loosing their essence, with 2 features out of 7 that have switched. The 2 others segments can be recognized (and re-mapped) but they lost their actionability. <br/>
# Costs ratio computed for those 2 separate periods are equivalent, around 2.7, meaining that 4 clusters has the same clustering efficiency (but of course larger clusters number could be found as new optimal).  <br/>
# For further proceedings, we need to decide what's matter for marketing, rising or stable or both to learn from data. <br/>

# %% [markdown]
# # 8. Explore K-Prototype to adress mixed-type features

# %% [markdown]
# To remedy the high unstability of K-Modes, we'll try K-Prototype. We saw that feature's discretization explains the root cause of unstability, because levels are highly sensistive to the threshold we've defined. <br/>
# We need to learn more about those feature's discretization to provide a stable target : a way to avoid this step is to consider K-Prorotype as the alternate way to catch the right behaviour for numerical features and categorical features.

# %% [markdown]
# ## 8.1. Preprocess Data

# %% [markdown]
# being aware of stability assessment, we first split the data into a baseline, and 8 month of additionnal customers.

# %%
# get back to features shortlist
features_shortlist
# Out:
# ['cust_sell_dist',
#  'product_price',
#  'product_qlty_index',
#  'product_review_mean',
#  'review_gap',
#  'charmed_price_cat',
#  'purchase_time_zone_cat',
#  'order_purchase_year',
#  'order_purchase_month']

# %%
# keep only use case features and temporal info
use_case_data = data.filter(features_shortlist)

# %%
use_case_data.columns
# Out:
# Index(['cust_sell_dist', 'product_price', 'product_qlty_index',
#        'product_review_mean', 'review_gap', 'charmed_price_cat',
#        'purchase_time_zone_cat', 'order_purchase_year',
#        'order_purchase_month'],
#       dtype='object')

# %%
# extract numerical features out of the shortlist
use_case_numerical = ['cust_sell_dist',
                      'product_price',
                      'product_qlty_index',
                      'product_review_mean',
                      'review_gap']

# %%
# reuse steps transform for numerical
numerical_pipeline = Pipeline(
    steps=[
        ('rankgauss', QuantileTransformer(n_quantiles=100,
                                          random_state=111,
                                          output_distribution='normal')),
        ('scaler', StandardScaler())
    ]
)

# %%
# num transformer
mynumtransformer = ColumnTransformer(
    transformers=[
        ('num', numerical_pipeline, use_case_numerical)],
    remainder='passthrough')

# %%
# apply transformer
mynumtransformer.fit(use_case_data)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num',
#                                  Pipeline(steps=[('rankgauss',
#                                                   QuantileTransformer(n_quantiles=100,
#                                                                       output_distribution='normal',
#                                                                       random_state=111)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['cust_sell_dist', 'product_price',
#                                   'product_qlty_index', 'product_review_mean',
#                                   'review_gap'])])

# %%
# apply columns to the transformed DataFrame
use_case_data_transformed = pd.DataFrame(mynumtransformer.transform(use_case_data), columns=use_case_data.columns)

# %%
# check results
use_case_data_transformed.sample(3)
# Out:
#       cust_sell_dist product_price product_qlty_index product_review_mean  \
# 81719      -0.214669       1.41825          -0.408089           -0.602074
# 59263        1.35378     -0.243128          -0.461634           -0.312948
# 73400       0.380519      0.699843          -0.162875             1.88057
#
#       review_gap charmed_price_cat purchase_time_zone_cat order_purchase_year  \
# 81719   -2.01159   Uncharmed_Price                  Night                2017
# 59263   0.875928     Charmed_Price                  Night                2017
# 73400  -0.238688   Uncharmed_Price                  AM-WD                2017
#
#       order_purchase_month
# 81719                    4
# 59263                   11
# 73400                    7

# %%
# any data represents now a new customer
plt.figure(figsize=(20, 5))
ax = sns.countplot(x='order_purchase_year',
                   hue='order_purchase_month',
                   data=use_case_data_transformed,
                   color='Steelblue')
ax.set(xlabel='Years',
       ylabel='Nb of new customers',
       title='Additionnal customers')
plt.legend(title='# month', loc='upper left')
plt.show()

# %%
# split baseline versus new customers
use_case_baseline = use_case_data_transformed[
    (use_case_data_transformed['order_purchase_year'] == 2017) |
    (use_case_data_transformed['order_purchase_year'] == 2016)]
use_case_new = use_case_data_transformed[
    (use_case_data_transformed['order_purchase_year'] == 2018)]

# %%
# size of baseline
use_case_baseline.shape
# Out:
# (38734, 9)

# %%
# remove useless colmuns
use_case_baseline = use_case_baseline.drop(
    columns=['order_purchase_year', 'order_purchase_month'])
use_case_new = use_case_new.drop(columns=['order_purchase_year'])

# %%
# isolate entire dataset
use_case_entire = use_case_data_transformed.drop(
    columns=['order_purchase_year', 'order_purchase_month'])

# %%
use_case_entire.shape
# Out:
# (87086, 7)

# %% [markdown]
# Thanks to the month, we will lately put new customers month by month

# %% [markdown]
# ## 8.2 Perform K-Prototype on entire dataset

# %%
kproto_4k_entire = KPrototypes(n_clusters=4, init='Cao', n_init=3, max_iter=30)
kproto_4k_entire.fit_predict(use_case_entire, categorical=[5, 6])
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=uint16)

# %%
# cost value
kproto_4k_entire.cost_
# Out:
# 309404.5324698753

# %%
# display centroids
for i in range(0, 4):
    print('cluster %d' % i)
    print(kproto_4k_entire.cluster_centroids_[0][i])
    print(kproto_4k_entire.cluster_centroids_[1][i])
# Out:
# cluster 0
# [ 0.11800997 -0.01336938  0.02191147 -0.48247636 -1.18451575]
# ['Charmed_Price' 'PM-WD']
# cluster 1
# [-0.6276694  -0.60219352 -0.40217011 -0.43783061  0.68682749]
# ['Charmed_Price' 'PM-WD']
# cluster 2
# [-0.07370308  0.07187897 -0.04735658  1.88056617 -0.24446508]
# ['Charmed_Price' 'PM-WD']
# cluster 3
# [ 0.54130325  0.54452893  0.4012663  -0.44505361  0.71018243]
# ['Charmed_Price' 'Evening-WD']

# %%
# go back to original values
use_case_data_visu = use_case_data.copy()
use_case_data_visu['kproto_cluster'] = kproto_4k_entire.labels_

# %%
# map to previous "similar" KModes clusters


def mapping(val):
    if (val == 1):
        return 0
    elif (val == 2):
        return 1
    elif (val == 0):
        return 2
    else:
        return val


# update cluster number
use_case_data_visu['kproto_cluster'] = use_case_data_visu['kproto_cluster'].apply(mapping).astype(int)

# %%
# clusters size
use_case_data_visu['kproto_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kproto clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kproto clusters size')

# %%
sns.catplot(x='kproto_cluster',
            y='product_price',
            kind='violin',
            inner='box',
            palette='Set2',
            data=use_case_data_visu[
                use_case_data_visu['product_price'] <= 400],
            height=3,
            aspect=10/5)

# %%
# mean sale price by clusters
df_mean_price_kproto = use_case_data_visu.groupby(
    'kproto_cluster',
    as_index=False).agg({'product_price': ['mean']})
df_mean_price_kproto.columns = ['kmodes_cluster',
                                'mean_price']

sns.barplot(y='kmodes_cluster',
            x='mean_price',
            data=df_mean_price_kproto,
            orient='h',
            palette='Set2').set_title('KProto 4k Mean Price by Cluster')
# Out:
# Text(0.5, 1.0, 'KProto 4k Mean Price by Cluster')

# %%
# visualiser les valeurs d'origine par cluster
for i in ['cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kproto_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=use_case_data_visu,
                height=3,
                aspect=10/5)

# %%
# Stacked barplot
charmed_ratio = use_case_data_visu.loc[
    use_case_data_visu['charmed_price_cat'] == 'Charmed_Price',
    :]['kproto_cluster'].value_counts()/data.shape[0]
uncharmed_ratio = use_case_data_visu.loc[
    use_case_data_visu['charmed_price_cat'] != 'Charmed_Price',
    :]['kproto_cluster'].value_counts()/data.shape[0]
df_charm = pd.DataFrame([charmed_ratio, uncharmed_ratio])
df_charm.index = ['PriceCharmed', 'Not_PriceCharmed']

# Plot
df_charm.plot(kind='barh',
              stacked=True,
              color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
              title='"Charm Price" effect accross clusters')
plt.xlabel('stacked Cluster ratio within Charm Price category')
plt.legend(title='kproto_cluster')

# %%
# Stacked barplot
PM_WD_ratio = use_case_data_visu.loc[
    use_case_data_visu['purchase_time_zone_cat'] == 'PM-WD',
    :]['kproto_cluster'].value_counts()/data.shape[0]
Evening_WD_ratio = use_case_data_visu.loc[
    use_case_data_visu['purchase_time_zone_cat'] == 'Evening-WD',
    :]['kproto_cluster'].value_counts()/data.shape[0]
WE_ratio = use_case_data_visu.loc[
    use_case_data_visu['purchase_time_zone_cat'] == 'WE',
    :]['kproto_cluster'].value_counts()/data.shape[0]
AM_WD_ratio = use_case_data_visu.loc[
    use_case_data_visu['purchase_time_zone_cat'] == 'AM-WD',
    :]['kproto_cluster'].value_counts()/data.shape[0]
Night_ratio = use_case_data_visu.loc[
    use_case_data_visu['purchase_time_zone_cat'] == 'Night',
    :]['kproto_cluster'].value_counts()/data.shape[0]
df_zone = pd.DataFrame([PM_WD_ratio,
                        Evening_WD_ratio,
                        WE_ratio,
                        AM_WD_ratio,
                        Night_ratio])
df_zone.index = ['PM-WD', 'Evening-WD', 'WE', 'AM-WD', 'Night']

# Plot
df_zone.plot(kind='barh',
             stacked=True,
             color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
             title='Purchase Time Zone accross clusters')
plt.xlim([0, 0.31])
plt.xlabel('stacked Cluster ratio within each Purchase Time Zone')
plt.legend(title='kproto_cluster')

# %% [markdown]
# ## 8.3. Assess stability - by comparison to "rising" (2017 - baseline)

# %%
use_case_baseline
# Out:
#       cust_sell_dist product_price product_qlty_index product_review_mean  \
# 48352       0.555382       -0.5506           0.399061           -0.249562
# 48353       0.899359      0.117763           0.583579           -0.214048
# 48354       0.266557       1.21307           -1.61414           -0.376919
# 48355       0.766787      0.530254            1.04502           -0.028188
# 48356      -0.976766     -0.463212           0.547033             1.88057
# ...              ...           ...                ...                 ...
# 87081       -2.15643      -2.39652          -0.925749             1.88057
# 87082       -2.15643      -2.35689          0.0450469             1.88057
# 87083       -1.21727        1.5958           0.337026             1.88057
# 87084       -1.26132       1.61879           -1.94794          -0.0594514
# 87085       0.930839      -1.41751           -1.18567           -0.501495
#
#       review_gap charmed_price_cat purchase_time_zone_cat
# 48352   0.743738     Charmed_Price                     WE
# 48353  -0.835014     Charmed_Price                     WE
# 48354    -1.6432     Charmed_Price                     WE
# 48355   0.311811     Charmed_Price                     WE
# 48356  -0.238688     Charmed_Price                     WE
# ...          ...               ...                    ...
# 87081  -0.238688     Charmed_Price                  AM-WD
# 87082  -0.238688     Charmed_Price                  AM-WD
# 87083  -0.238688     Charmed_Price                  PM-WD
# 87084   0.380428     Charmed_Price                  AM-WD
# 87085  -0.238688     Charmed_Price                  PM-WD
#
# [38734 rows x 7 columns]

# %%
# cost as a function of n_clusters
time_start = time.time()
kproto_results_scan = []
for n_clusters in range(1, 10):
    kproto_scan = KPrototypes(n_clusters=n_clusters, init='Cao', n_init=1, max_iter=30)
    kproto_scan.fit_predict(use_case_baseline, categorical=[5, 6])
    kproto_results_scan.append(kproto_scan.cost_)
print('kproto k scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# 5:80: E501 line too long (87 > 79 characters)
# kproto k scan, elapsed time: 721.759507894516 seconds

# %%
# costs decrease
y = np.array([i for i in range(1, 10)])
plt.plot(y, kproto_results_scan)
plt.title('KProto cost values by clusters nb')
# Out:
# Text(0.5, 1.0, 'KProto cost values by clusters nb')

# %%
kproto_4k = KPrototypes(n_clusters=4, init='Cao', n_init=3, max_iter=30)
kproto_4k.fit_predict(use_case_baseline, categorical=[5, 6])
# Out:
# array([3, 0, 0, ..., 1, 2, 2], dtype=uint16)

# %%
# display centroids
for i in range(0, 4):
    print('cluster %d' % i)
    print(kproto_4k.cluster_centroids_[0][i])
    print(kproto_4k.cluster_centroids_[1][i])
# Out:
# cluster 0
# [ 0.11948145 -0.05964411 -0.00342884 -0.47637414 -1.16236305]
# ['Charmed_Price' 'Evening-WD']
# cluster 1
# [ 0.00621902  0.08896975 -0.04851418  1.88056617 -0.24332229]
# ['Charmed_Price' 'Evening-WD']
# cluster 2
# [-0.51142471 -0.59043502 -0.28226923 -0.43381592  0.7431806 ]
# ['Charmed_Price' 'PM-WD']
# cluster 3
# [ 0.6261683   0.63176103  0.31484776 -0.44206668  0.67689189]
# ['Charmed_Price' 'Evening-WD']

# %%
# cost value
kproto.cost_
# Out:
# 133531.42273852316

# %%
origin_data_baseline = data[
    (data['order_purchase_year'] == 2017) |
    (data['order_purchase_year'] == 2016)]

# %%
# go back to original values
use_case_baseline = origin_data_baseline.copy()
use_case_baseline['kproto_cluster'] = kproto_4k.labels_

# %%
# map to previous "similar" KModes clusters


def mapping_compare(val):
    if (val == 0):
        return 2
    elif (val == 1):
        return 0
    elif (val == 2):
        return 1
    else:
        return val


# update cluster number
use_case_baseline['kproto_cluster'] = use_case_baseline['kproto_cluster'].apply(mapping_compare).astype(int)

# %%
# clusters size
use_case_baseline['kproto_cluster'].value_counts(sort=False).plot(
    kind='barh',
    color=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3'],
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('nb of customers', labelpad=14)
plt.ylabel('clusters')
plt.title('kproto clusters size', y=1.02)
# Out:
# Text(0.5, 1.02, 'kproto clusters size')

# %%
# mean sale price by clusters
df_mean_price_kproto_baseline = use_case_baseline.groupby(
    'kproto_cluster',
    as_index=False).agg({'product_price': ['mean']})
df_mean_price_kproto_baseline.columns = ['kmodes_cluster',
                                         'mean_price']

sns.barplot(y='kmodes_cluster',
            x='mean_price',
            data=df_mean_price_kproto_baseline,
            orient='h',
            palette='Set2').set_title('KProto 4k Mean Price by Cluster - Baseline')
# Out:
# Text(0.5, 1.0, 'KProto 4k Mean Price by Cluster - Baseline')

# %%
sns.catplot(x='kproto_cluster',
            y='product_price',
            kind='violin',
            inner='box',
            palette='Set2',
            data=use_case_baseline[
                use_case_baseline['product_price'] <= 400],
            height=3,
            aspect=10/5)

# %%
# visualiser les valeurs d'origine par cluster
for i in ['cust_sell_dist',
          'product_qlty_index',
          'product_review_mean',
          'review_gap']:
    sns.catplot(x='kproto_cluster',
                y=i,
                kind='violin',
                inner='box',
                palette='Set2',
                data=use_case_baseline,
                height=3,
                aspect=10/5)

# %% [markdown]
# Here we get pretty stable cluster, considering any features of our use case !
# In the meantime, we see that categorical features aren't as much disciminating than with K-Modes, meaning a further proceeding could be to go on weighted K-Prototype. <br/>
# Let's consider this as further work to discuss with marketing team, and build a more precise procedure to assess stability.

# %% [markdown]
# ## 8.4. Assess stability : dissimilarity trend after aggregation

# %% [markdown]
# To implement this more accurate method (here considering each month as a new set of customers), we need to compute clustering on a baseline : the 2017 rising period, and split the 2018 stable period into monthly new customers to consider. <br/>
#
# We compute the ARI to see how those new customers have altered our target, i.e. is the customer still in the same "baseline" cluster? if not, ARI will decrease, if we see a drop, this means we have to review our clustering target according to new trends that new customers carry on.

# %%
# get back to baseline
use_case_baseline
# Out:
#       cust_sell_dist product_price product_qlty_index product_review_mean  \
# 48352       0.555382       -0.5506           0.399061           -0.249562
# 48353       0.899359      0.117763           0.583579           -0.214048
# 48354       0.266557       1.21307           -1.61414           -0.376919
# 48355       0.766787      0.530254            1.04502           -0.028188
# 48356      -0.976766     -0.463212           0.547033             1.88057
# ...              ...           ...                ...                 ...
# 87081       -2.15643      -2.39652          -0.925749             1.88057
# 87082       -2.15643      -2.35689          0.0450469             1.88057
# 87083       -1.21727        1.5958           0.337026             1.88057
# 87084       -1.26132       1.61879           -1.94794          -0.0594514
# 87085       0.930839      -1.41751           -1.18567           -0.501495
#
#       review_gap charmed_price_cat purchase_time_zone_cat
# 48352   0.743738     Charmed_Price                     WE
# 48353  -0.835014     Charmed_Price                     WE
# 48354    -1.6432     Charmed_Price                     WE
# 48355   0.311811     Charmed_Price                     WE
# 48356  -0.238688     Charmed_Price                     WE
# ...          ...               ...                    ...
# 87081  -0.238688     Charmed_Price                  AM-WD
# 87082  -0.238688     Charmed_Price                  AM-WD
# 87083  -0.238688     Charmed_Price                  PM-WD
# 87084   0.380428     Charmed_Price                  AM-WD
# 87085  -0.238688     Charmed_Price                  PM-WD
#
# [38734 rows x 7 columns]

# %%
# initialize KPrototype for 4 clusters with light parameters
kproto = KPrototypes(n_clusters=4, init='Cao', n_init=3, max_iter=30)

# %%
# predict original labels
time_start = time.time()
kproto.fit_predict(use_case_baseline, categorical=[5, 6])
print('kproto original clustering, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kproto original clustering, elapsed time: 250.9742341041565 seconds

# %%
# build baseline
baseline_labels = kproto.labels_
labeled_baseline = use_case_baseline.copy()
labeled_baseline['original_cluster'] = baseline_labels
labeled_baseline
# Out:
#       cust_sell_dist product_price product_qlty_index product_review_mean  \
# 48352       0.555382       -0.5506           0.399061           -0.249562
# 48353       0.899359      0.117763           0.583579           -0.214048
# 48354       0.266557       1.21307           -1.61414           -0.376919
# 48355       0.766787      0.530254            1.04502           -0.028188
# 48356      -0.976766     -0.463212           0.547033             1.88057
# ...              ...           ...                ...                 ...
# 87081       -2.15643      -2.39652          -0.925749             1.88057
# 87082       -2.15643      -2.35689          0.0450469             1.88057
# 87083       -1.21727        1.5958           0.337026             1.88057
# 87084       -1.26132       1.61879           -1.94794          -0.0594514
# 87085       0.930839      -1.41751           -1.18567           -0.501495
#
#       review_gap charmed_price_cat purchase_time_zone_cat  original_cluster
# 48352   0.743738     Charmed_Price                     WE                 3
# 48353  -0.835014     Charmed_Price                     WE                 2
# 48354    -1.6432     Charmed_Price                     WE                 2
# 48355   0.311811     Charmed_Price                     WE                 3
# 48356  -0.238688     Charmed_Price                     WE                 0
# ...          ...               ...                    ...               ...
# 87081  -0.238688     Charmed_Price                  AM-WD                 0
# 87082  -0.238688     Charmed_Price                  AM-WD                 0
# 87083  -0.238688     Charmed_Price                  PM-WD                 0
# 87084   0.380428     Charmed_Price                  AM-WD                 1
# 87085  -0.238688     Charmed_Price                  PM-WD                 1
#
# [38734 rows x 8 columns]

# %%
# get back to use_case_data_transformed with purchase_month
additional = use_case_data_transformed[
    (use_case_data_transformed['order_purchase_year'] == 2018)]

# %%
# once cutted, remove year indication
additional.drop(['order_purchase_year'], axis=1, inplace=True)

# %%
# built month list
month = list(range(1, 9))

# %%
# check aggregation
for i in range(1, 9):
    addition = additional[additional['order_purchase_month'].isin(
            month[:i])]
    addition.drop(['order_purchase_month'], axis=1, inplace=True)
    print(addition.shape)
# Out:
# (6240, 7)
# (12059, 7)
# (18365, 7)
# (24621, 7)
# (30866, 7)
# (36515, 7)
# (42312, 7)
# (48352, 7)

# %%
# one shot entire data ari calculation
time_start = time.time()
kproto = KPrototypes(n_clusters=4, init='Cao', n_init=3, max_iter=30)
total = use_case_baseline.append(addition)
total_new_labels = kproto.fit_predict(total, categorical=[5, 6])
labeled_total = total.copy()
labeled_total['new_cluster'] = total_new_labels
merged = labeled_baseline.merge(labeled_total)
adj_rand_index = adjusted_rand_score(
    merged['original_cluster'], merged['new_cluster'])
print('kproto final scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kproto final scan, elapsed time: 656.2727897167206 seconds

# %%
# ari value final
adj_rand_index
# Out:
# 0.9066660407825099

# %%
# compute kproto and ari month by month
time_start = time.time()
ari_list = []
kproto = KPrototypes(n_clusters=4, init='Cao', n_init=3, max_iter=30)
for i in range(1, 9):
    # create addition
    addition = additional[additional['order_purchase_month'].isin(
            month[:i])]
    addition.drop(['order_purchase_month'], axis=1, inplace=True)
    # baseline updated with addition
    total = use_case_baseline.append(addition)
    # compute new clustering
    total_new_labels = kproto.fit_predict(total, categorical=[5, 6])
    # paste new labels
    labeled_total = total.copy()
    labeled_total['new_cluster'] = total_new_labels
    # merge results to baseline
    merged = labeled_baseline.merge(labeled_total)
    # compute adj rand index
    adj_rand_index = adjusted_rand_score(
        merged['original_cluster'], merged['new_cluster'])
    ari_list.append(adj_rand_index)
print('kproto stability scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kproto stability scan, elapsed time: 3827.55886220932 seconds

# %%
# ari evolution
x = np.array([i for i in range(1, 9)])
plt.plot(x, ari_list)
plt.ylim((0.6, 1))
plt.ylabel('ARI')
plt.xlabel('additional months')
plt.title('adj rand index along monthly customers aggregation')
# Out:
# Text(0.5, 1.0, 'adj rand index along monthly customers aggregation')

# %% [markdown]
# This way, stability is ensured in this use case through K-Prototypes, even with ability to match better as long as new customers have been taken into account. We should mind the duration of such computation, in comparison with simple KMeans, but not an obstacle in a commercial perspective.

# %% [markdown]
# ## 8.5. Assess stability versus KMeans

# %% [markdown]
# One last attempt concerns KMeans in terms of stability perspective, because not yet assessed in our work.

# %%
# split baseline versus new customers
use_case_baseline = use_case_data_transformed[
    (use_case_data_transformed['order_purchase_year'] == 2017) |
    (use_case_data_transformed['order_purchase_year'] == 2016)]
additional = use_case_data_transformed[
    (use_case_data_transformed['order_purchase_year'] == 2018)]

# %%
# remove categories
use_case_baseline = use_case_baseline.drop(
    columns=['charmed_price_cat', 'purchase_time_zone_cat'])
additional = additional.drop(
    columns=['charmed_price_cat', 'purchase_time_zone_cat'])

# %%
# remove useless colmuns
use_case_baseline = use_case_baseline.drop(
    columns=['order_purchase_year', 'order_purchase_month'])
additional = additional.drop(columns=['order_purchase_year'])

# %%
# initialize Kmeans for 4 clusters with light parameters
kmeans_stab = KMeans(n_clusters=4)

# %%
# predict original labels
time_start = time.time()
kmeans_stab.fit_predict(use_case_baseline)
print('kmeans original clustering, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kmeans original clustering, elapsed time: 1.1659460067749023 seconds

# %%
# build baseline
baseline_labels = kmeans_stab.labels_
labeled_baseline = use_case_baseline.copy()
labeled_baseline['original_cluster'] = baseline_labels
labeled_baseline
# Out:
#       cust_sell_dist product_price product_qlty_index product_review_mean  \
# 48352       0.555382       -0.5506           0.399061           -0.249562
# 48353       0.899359      0.117763           0.583579           -0.214048
# 48354       0.266557       1.21307           -1.61414           -0.376919
# 48355       0.766787      0.530254            1.04502           -0.028188
# 48356      -0.976766     -0.463212           0.547033             1.88057
# ...              ...           ...                ...                 ...
# 87081       -2.15643      -2.39652          -0.925749             1.88057
# 87082       -2.15643      -2.35689          0.0450469             1.88057
# 87083       -1.21727        1.5958           0.337026             1.88057
# 87084       -1.26132       1.61879           -1.94794          -0.0594514
# 87085       0.930839      -1.41751           -1.18567           -0.501495
#
#       review_gap  original_cluster
# 48352   0.743738                 0
# 48353  -0.835014                 1
# 48354    -1.6432                 1
# 48355   0.311811                 0
# 48356  -0.238688                 2
# ...          ...               ...
# 87081  -0.238688                 2
# 87082  -0.238688                 2
# 87083  -0.238688                 2
# 87084   0.380428                 3
# 87085  -0.238688                 3
#
# [38734 rows x 6 columns]

# %%
# compute kmeans and ari month by month
time_start = time.time()
ari_list = []
kmeans_stab = KMeans(n_clusters=4)
for i in range(1, 9):
    # create addition
    addition = additional[additional['order_purchase_month'].isin(
            month[:i])]
    addition.drop(['order_purchase_month'], axis=1, inplace=True)
    # baseline updated with addition
    total = use_case_baseline.append(addition)
    # compute new clustering
    total_new_labels = kmeans_stab.fit_predict(total)
    # paste new labels
    labeled_total = total.copy()
    labeled_total['new_cluster'] = total_new_labels
    # merge results to baseline
    merged = labeled_baseline.merge(labeled_total)
    # compute adj rand index
    adj_rand_index = adjusted_rand_score(
        merged['original_cluster'], merged['new_cluster'])
    ari_list.append(adj_rand_index)
print('kproto stability scan, elapsed time: {} seconds'.format(time.time()-time_start))
# Out:
# kproto stability scan, elapsed time: 17.795441150665283 seconds

# %%
# ari evolution
x = np.array([i for i in range(1, 9)])
plt.plot(x, ari_list)
plt.ylim((0.6, 1))
plt.ylabel('ARI')
plt.xlabel('additional months')
plt.title('kmeans adj rand index along monthly customers aggregation')
# Out:
# Text(0.5, 1.0, 'kmeans adj rand index along monthly customers aggregation')

# %% [markdown]
# We reached a similar stability with Kmeans restricted to numerical features.
