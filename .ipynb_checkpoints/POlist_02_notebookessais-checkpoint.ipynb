# %%
# %load_ext pycodestyle_magic
# %flake8_on
# la convention PEP8 est ainsi testée
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %%
# importer les packages
# common
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# ml
from sklearn.preprocessing import StandardScaler, QuantileTransformer, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.decomposition import FactorAnalysis
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.cluster import AgglomerativeClustering
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, DBSCAN
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score as dbsc
from kmodes.kmodes import KModes
# plot
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# 10:80: E501 line too long (84 > 79 characters)
# 1: E999 SyntaxError: invalid syntax

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.2'

# %%
# récupérer les données
data = pd.read_csv('Data/data.csv')

# %%
data.sample(5)
# Out:
#                                order_id                       customer_id  \
# 73216  bb4c68c40aab77380324d2d741782056  70c99b15ec648bc2c97997dd3516ec93
# 67437  306d73cb716b08d3525396fb16493d3a  02419e623129afb04b8cc41e737d2702
# 84700  a526b3be214b1d691e5400d86689e83e  d45f8333c8aa989e25029e9e0cadcf7a
# 52875  226e16e7eb6dcefe180d80127468de8b  1063de5cc98f570e53eccb32723746e2
# 36255  f9d2dfcbc89dc4d66e0848019d99bfc9  a6578491147295b1ff31962e01ed8a13
#
#       order_purchase_timestamp  order_purchase_year  order_purchase_month  \
# 73216      2017-07-25 22:22:57                 2017                     7
# 67437      2017-09-11 22:32:54                 2017                     9
# 84700      2017-03-24 07:22:04                 2017                     3
# 52875      2017-12-06 16:52:25                 2017                    12
# 36255      2018-03-03 20:26:50                 2018                     3
#
#        order_purchase_day  order_purchase_dayofweek  order_purchase_hour  \
# 73216                  25                         1                   22
# 67437                  11                         0                   22
# 84700                  24                         4                    7
# 52875                   6                         2                   16
# 36255                   3                         5                   20
#
#       order_purchase_month_label order_purchase_dayofweek_label  ...  \
# 73216                        Jul                            Tue  ...
# 67437                        Sep                            Mon  ...
# 84700                        Mar                            Fri  ...
# 52875                        Dec                            Wed  ...
# 36255                        Mar                            Sat  ...
#
#       main_payment_type_debit_card main_payment_type_voucher  \
# 73216                            0                         0
# 67437                            0                         0
# 84700                            0                         0
# 52875                            0                         0
# 36255                            0                         0
#
#       main_payment_type_cat_Credit_Card_PayType  \
# 73216                                         1
# 67437                                         1
# 84700                                         1
# 52875                                         1
# 36255                                         1
#
#        main_payment_type_cat_Other_PayType  N_RG_payment_total  \
# 73216                                    0           -0.595127
# 67437                                    0            0.222825
# 84700                                    0            0.948333
# 52875                                    0            1.236005
# 36255                                    0           -1.199904
#
#        N_RG_freight_percentage N_RG_product_review_mean N_RG_review_gap  \
# 73216                 0.401453                -0.786264        1.487341
# 67437                -0.675710                -1.248739        2.080082
# 84700                -1.014342                 5.199338       -0.242903
# 52875                 0.920402                -0.216904        1.011683
# 36255                 0.713570                -0.012660        0.826108
#
#       N_RG_delivery_vs_estimated N_RG_cust_sell_dist
# 73216                   1.029957            0.764510
# 67437                  -0.063341            0.165327
# 84700                  -0.063341            0.410809
# 52875                  -0.178175            1.267676
# 36255                  -0.574460           -1.549706
#
# [5 rows x 97 columns]

# %%
data.select_dtypes(include='number').columns
# Out:
# Index(['order_purchase_year', 'order_purchase_month', 'order_purchase_day',
#        'order_purchase_dayofweek', 'order_purchase_hour',
#        'estimated_delivery_time', 'effective_delivery_time',
#        'delivery_vs_estimated', 'total_price', 'total_freight',
#        'freight_percentage', 'product_price', 'product_freight', 'charm_price',
#        'product_name_length', 'product_description_length',
#        'product_photos_qty', 'product_weight_g', 'product_size',
#        'main_payment_value', 'payment_sequence_size',
#        'payment_installments_size', 'payment_total', 'N_SCALE_payment_total',
#        'seller_lat', 'seller_lng', 'order_count', 'customer_lat',
#        'customer_lng', 'cust_sell_dist', 'review_score', 'review_answer_delay',
#        'product_review_count', 'product_review_mean', 'customer_review_count',
#        'customer_review_mean', 'review_gap', 'rational_category_Auto',
#        'rational_category_Construction & Tools', 'rational_category_Corporate',
#        'rational_category_Electronics Computers & Accessories',
#        'rational_category_Entertainement', 'rational_category_Fashion',
#        'rational_category_Food Drink & Pets', 'rational_category_Furniture',
#        'rational_category_Health Beauty Baby',
#        'rational_category_Home Accessories',
#        'rational_category_Home Appliances', 'rational_category_Sports Leisure',
#        'rational_category_Supplies', 'rational_category_Telephony',
#        'rational_category_Watches Gifts Toys', 'purchase_time_zone_AM-WD',
#        'purchase_time_zone_Evening-WD', 'purchase_time_zone_Night',
#        'purchase_time_zone_PM-WD', 'purchase_time_zone_WE',
#        'main_payment_type_boleto', 'main_payment_type_credit_card',
#        'main_payment_type_debit_card', 'main_payment_type_voucher',
#        'main_payment_type_cat_Credit_Card_PayType',
#        'main_payment_type_cat_Other_PayType', 'N_RG_payment_total',
#        'N_RG_freight_percentage', 'N_RG_product_review_mean',
#        'N_RG_review_gap', 'N_RG_delivery_vs_estimated', 'N_RG_cust_sell_dist'],
#       dtype='object')

# %%
numerical_features = ['payment_total',
                      'freight_percentage',
                      'product_review_mean',
                      'review_gap',
                      'delivery_vs_estimated',
                      'cust_sell_dist']

categorical_features = ['rational_category',
                        'purchase_time_zone',
                        'main_payment_type',
                        'main_payment_type_cat']

# %%
numerical_pipeline = make_pipeline(StandardScaler())
categorical_pipeline = make_pipeline(OneHotEncoder())
numerical_features = make_column_selector(dtype_include='number')
categorical_features = make_column_selector(dtype_include='category')

# %%
mytransformer = make_column_transformer(
    (numerical_pipeline, numerical_features),
    (categorical_pipeline, categorical_features))

# %%
mypipe = make_pipeline(mytransformer, clusterer)

# %%
mypipe.fit(data)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['payment_total',
#                                                    'freight_percentage',
#                                                    'product_review_mean',
#                                                    'review_gap',
#                                                    'delivery_vs_estimated',
#                                                    'cust_sell_dist']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['rational_category',
#                                                    'purchase_time_zone',
#                                                    'main_payment_type',
#                                                    'main_payment_type_cat'])]))])

# %%
data_sample_10 = pd.DataFrame(data).sample(
    int(data.shape[0]/10),
    random_state=42)
data_sample_10.shape
# Out:
# (9036, 105)

# %%
data_sample_20 = pd.DataFrame(data).sample(
    int(data.shape[0]/5),
    random_state=42)
data_sample_20.shape
# Out:
# (18072, 105)

# %%
# rappel des features
# pour découper des jeux de données temporelles
temporal_cut_features = ['order_purchase_year', 'order_purchase_month']
# pour décrire les clusters (on retire les données produits)
for_lvl_features = ['eq_payment_lvl',
                    'delivery_vs_estimated_lvl',
                    'freight_percentage_lvl',
                    'cust_sell_dist_lvl',
                    'review_gap_lvl']
# pour décrire les catégories de produit
cat_feat_product = data.columns[data.columns.str.contains(
    'rational_category_')].tolist()
# pour identifier les moments d'achat
cat_feat_order = data.columns[data.columns.str.contains(
    'purchase_time_zone_')].tolist()
# pour identifier le moyen de paiement
cat_feat_payment = data.columns[data.columns.str.contains(
    'main_payment_type')].tolist()

# %%
HClust_selection = ['N_RG_payment_total', 'N_RG_product_review_mean', 'N_RG_cust_sell_dist']

# %%
# projection des données sur les features
data_selection = data.filter(HClust_selection + cat_feat_order)
data_selection.shape
# Out:
# (90360, 8)

# %%
data_selection.sample(3)
# Out:
#        N_RG_payment_total  N_RG_product_review_mean  N_RG_cust_sell_dist  \
# 56495            0.496960                 -0.223343             0.392334
# 44719            0.952584                 -0.755054            -0.174083
# 7365             0.718860                 -0.416878            -0.688670
#
#        purchase_time_zone_AM-WD  purchase_time_zone_Evening-WD  \
# 56495                         1                              0
# 44719                         0                              1
# 7365                          1                              0
#
#        purchase_time_zone_Night  purchase_time_zone_PM-WD  \
# 56495                         0                         0
# 44719                         0                         0
# 7365                          0                         0
#
#        purchase_time_zone_WE
# 56495                      0
# 44719                      0
# 7365                       0

# %%
# projection des données sur les features
data_sel_sample10 = data_sample_10.filter(HClust_selection)
data_sel_sample20 = data_sample_20.filter(HClust_selection)

# %% [markdown]
# # Clustering hierarchique

# %% [markdown]
# ##  Distances : Euclidienne, Mahalabonis, CityBlock
# Observations sur des échantillons de 10 et 20% des données.

# %%
cl_eucl_10 = linkage(data_sel_sample10, method='complete', metric='euclidean')

# %%
cl_eucl_20 = linkage(data_sel_sample20, method='complete', metric='euclidean')

# %%
cl_mahal_10 = linkage(data_sel_sample10, method='complete', metric='mahalanobis')

# %%
cl_mahal_20 = linkage(data_sel_sample20, method='complete', metric='mahalanobis')

# %%
cl_citybl_10 = linkage(data_sel_sample10, method='complete', metric='cityblock')

# %%
cl_citybl_20 = linkage(data_sel_sample20, method='complete', metric='cityblock')

# %%
def dendo(cl1, cl2, cl1_label, cl2_label):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[12, 5])
    ax1.set_xlabel('Customers', fontsize=12)
    ax1.set_ylabel('Distance', fontsize=12)
    ax1.set_title('Dendrogram ' + cl1_label, fontsize=13)
    ax1.tick_params(axis='both', which='major', labelsize=13)
    dendrogram(cl1,
               leaf_rotation=90,
               leaf_font_size=12,
               truncate_mode='lastp',
               show_leaf_counts=True,
               ax=ax1,
               )
    ax2.set_xlabel('Clients', fontsize=12)
    ax2.set_ylabel('Distance', fontsize=12)
    ax2.set_title('Dendrogram ' + cl2_label, fontsize=13)
    ax2.tick_params(axis='both', which='major', labelsize=13)
    dendrogram(cl2,
               leaf_rotation=90,
               leaf_font_size=12,
               truncate_mode='lastp',
               show_leaf_counts=True,
               ax=ax2)
    plt.show()

# %%
dendo(cl_eucl_10, cl_eucl_20, 'Euclidian_10', 'Euclidian_20')

# %%
dendo(cl_mahal_10, cl_mahal_20, 'Mahalabonis_10', 'Mahalabonis_20')

# %%
dendo(cl_citybl_10, cl_citybl_20, 'CityBlock_10', 'CityBlock_20')

# %% [markdown]
# - la claissification hiérachique la plus exploitable semble construire à partir de la distance euclidienne et s'améliore avec la taille de l'échantillon

# %%
HClustLabels = fcluster(cl_mahal_20, 3, criterion='maxclust')

# %%
HClust = data_sel_sample20.copy()

# %%
HClust['clusters'] = HClustLabels

# %%
HClust.sample(5)
# Out:
#        N_RG_payment_total  N_RG_product_review_mean  N_RG_cust_sell_dist  \
# 30316           -0.752793                  0.721329            -0.671448
# 84402           -1.510188                  0.764710            -1.080810
# 63896           -1.813727                  5.199338            -0.135620
# 38642           -0.472968                  0.086616             0.682146
# 5210            -0.918920                  5.199338            -0.379968
#
#        clusters
# 30316         2
# 84402         2
# 63896         3
# 38642         2
# 5210          3

# %%
metrics.davies_bouldin_score(
        data_sel_sample20,
        HClustLabels)
# Out:
# 1.330246824593707

# %%
n_clusters = list(range(2, 9))

# %%
n_clusters
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
def cv_davies_bouldin_score(estimator, X):
    estimator.fit(X)
    cluster_labels = estimator.labels_
    num_labels = len(set(cluster_labels))
    num_samples = len(X.index)
    if num_labels == 1 or num_labels == num_samples:
        return -1
    else:
        return dbsc(X, cluster_labels)

# %%
ss = ShuffleSplit(test_size=0.20, n_splits=1, random_state=42)

# %%
data_sel_sample20.shape
# Out:
# (18072, 3)

# %%
ss.get_n_splits(data_sel_sample20)
# Out:
# 1

# %%
ss.split(data_sel_sample20)
# Out:
# <generator object BaseShuffleSplit.split at 0x00000228A5C455C8>

# %%
# Parameters of can be set using ‘__’ separated parameter names:
param_grid = {
    'linkage': ['complete',
                'ward'],
    'n_clusters': list(range(1, 3))
}

# %%
gs = GridSearchCV(estimator=AgglomerativeClustering(),
                  param_grid=param_grid,
                  scoring=cv_davies_bouldin_score,
                  cv=ShuffleSplit(test_size=0.20, n_splits=1, random_state=42),
                  n_jobs=-1)

# %%
gs.fit(data_sel_sample20)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=1, random_state=42, test_size=0.2, train_size=None),
#              error_score='raise-deprecating',
#              estimator=AgglomerativeClustering(affinity='euclidean',
#                                                compute_full_tree='auto',
#                                                connectivity=None,
#                                                distance_threshold=None,
#                                                linkage='ward', memory=None,
#                                                n_clusters=2,
#                                                pooling_func='deprecated'),
#              iid='warn', n_jobs=-1,
#              param_grid={'linkage': ['complete', 'ward'], 'n_clusters': [1, 2]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=<function cv_davies_bouldin_score at 0x00000228A98A33A8>,
#              verbose=0)

# %%
gs.cv_results_
# Out:
# {'mean_fit_time': array([45.45422506, 45.34312153, 49.45266747, 49.32866526]),
#  'std_fit_time': array([0., 0., 0., 0.]),
#  'mean_score_time': array([1.8124845 , 2.18583417, 0.99691391, 0.99712729]),
#  'std_score_time': array([0., 0., 0., 0.]),
#  'param_linkage': masked_array(data=['complete', 'complete', 'ward', 'ward'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_clusters': masked_array(data=[1, 2, 1, 2],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'linkage': 'complete', 'n_clusters': 1},
#   {'linkage': 'complete', 'n_clusters': 2},
#   {'linkage': 'ward', 'n_clusters': 1},
#   {'linkage': 'ward', 'n_clusters': 2}],
#  'split0_test_score': array([-1.        ,  0.58432684, -1.        ,  0.5538595 ]),
#  'mean_test_score': array([-1.        ,  0.58432684, -1.        ,  0.5538595 ]),
#  'std_test_score': array([0., 0., 0., 0.]),
#  'rank_test_score': array([3, 1, 3, 2])}

# %%
gs.best_params_
# Out:
# {'linkage': 'complete', 'n_clusters': 2}

# %%
gs.best_score_
# Out:
# 0.5843268391549509

# %%
# projection des données sur les features
data_selection = data.filter(HClust_selection + cat_feat_order)
data_selection.shape

# %%
clust = linkage(data_sel_sample10)

# %%
scale = StandardScaler()

# %%
pipe = Pipeline(steps=[('scale', 'passthrough'), ('clust', 'passthrough')])

# %%
search.fit(X_digits, y_digits)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)

# %%
# observer la répartition des effectifs dans les clusters
HClust['clusters'].value_counts(sort=False).plot(
    kind='barh',
    color='steelblue',
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('Cluster pop', labelpad=14)
plt.title('Cluster nb', y=1.02)
# Out:
# Text(0.5, 1.02, 'Cluster nb')

# %%
HClust1 = HClust[HClust['clusters'] == 1]
HClust1.name = 'cluster 1'
HClust2 = HClust[HClust['clusters'] == 2]
HClust2.name = 'cluster 2'
HClust3 = HClust[HClust['clusters'] == 3]
HClust3.name = 'cluster 3'

# %%
def SalesClust(data):
    SalesClust = data.groupby(
        'rational_category',
        as_index=False).agg({'payment_total': ['sum']})
    SalesClust.columns = ['rational_category',
                          'sales']
    SalesClust = SalesClust.sort_values(by=['sales'],
                                        ascending=False)
    fig, ax = plt.subplots(figsize=(3, 3))
    ax = sns.barplot(y='rational_category',
                     x='sales',
                     color='Steelblue',
                     data=SalesClust[:5])
    ax.set(xlabel='Sales Revenue',
           ylabel='Products Categories',
           title='Top 5 Sales by Category : ' + str(data.name))

# %%
for i in [HClust1, HClust2, HClust3]:
    SalesClust(i)

# %%
label_color_map = {1: 'r',
                   2: 'k',
                   3: 'b'}

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(HClust['N_RG_payment_total'],
           HClust['N_RG_product_review_mean'],
           HClust['N_RG_cust_sell_dist'],
           cmap='plasma',
           c=HClust['clusters'])
ax.view_init(elev=10, azim=45)
ax.set_xlabel('Rank-Gaussed Payment Total', labelpad=15)
ax.set_ylabel('Rank-Gaussed Product Review Mean', labelpad=15)
ax.set_zlabel('Rank-Gaussed Cust_Sell distance')
# Out:
# Text(0.5, 0, 'Rank-Gaussed Cust_Sell distance')

# %%
HClust.groupby('purchase_time_zone').clusters.value_counts().plot(
        kind='barh',
        color='steelblue',
        figsize=(5, 5)).invert_yaxis()
plt.xlabel('Orders Qty', labelpad=14)
plt.title('Purchase Time Zones', y=1.02)
# Out:
# Text(0.5, 1.02, 'Purchase Time Zones')

# %% [markdown]
# - on conclue à une répartition homogène des achats par moment de la semaine

# %% [markdown]
# # PCA
# On déroule une PCA en commençant par les features selectionnés

# %%
data_selection.sample(3)
# Out:
#        N_RG_payment_total  N_RG_product_review_mean  N_RG_cust_sell_dist  \
# 35036            1.041021                  5.199338             1.049316
# 84019            0.351133                 -0.889495             0.350694
# 16473           -1.625957                  0.625618             0.414027
#
#        purchase_time_zone_AM-WD  purchase_time_zone_Evening-WD  \
# 35036                         0                              0
# 84019                         0                              1
# 16473                         1                              0
#
#        purchase_time_zone_Night  purchase_time_zone_PM-WD  \
# 35036                         0                         0
# 84019                         0                         0
# 16473                         0                         0
#
#        purchase_time_zone_WE
# 35036                      1
# 84019                      0
# 16473                      0

# %%
# aperçu sur 2 dimensions
pca = PCA(n_components=2)
pca_n2 = pca.fit_transform(data_selection)
pca_df = pd.DataFrame(
    data=pca_n2, columns=['F1',
                          'F2'])

# %%
# afficher les données selon les 2 dimensions
plt.scatter(pca_df['F1'], pca_df['F2'], alpha=.2)

# %%
# variance
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.58601883 0.23988466]
# 0.8259034948798403

# %%
# contribution des variables aux 2 composantes
pcs = pca.components_

fig = plt.figure(figsize=(10, 10))
for i, (x, y) in enumerate(zip(pcs[0, :], pcs[1, :])):
    plt.plot([0, x], [0, y])
    plt.text(x, y, data_selection.columns[i])
plt.plot([-1.1, 1.1], [0, 0], color='grey', ls='--')
plt.plot([0, 0], [-1.1, 1.1], color='grey', ls='--')
plt.xlim([-1.1, 1.1])
plt.ylim([-1.1, 1.1])
# Out:
# (-1.1, 1.1)

# %%
# avec 3 composants
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(data_selection)
principalDf = pd.DataFrame(
    data=principalComponents, columns=['F1',
                                       'F2',
                                       'F3'])

# %%
# afficher les données selon les 3 dimensions
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.set_xlabel('F1', fontsize=15)
ax.set_ylabel('F2', fontsize=15)
ax.set_zlabel('F3', fontsize=15)
ax.set_title('PCA n_components=3', fontsize=20)

ax.scatter(principalDf['F1'],
           principalDf['F2'],
           principalDf['F3'],
           s=60,
           alpha=0.2)
ax.grid()

# %%
# variance
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.58601883 0.23988466 0.09399317]
# 0.9198966653287904

# %%
# nombre optimal de components
pca = PCA()
pca.fit(data_selection)
cumsum = np.cumsum(pca.explained_variance_ratio_)

# %%
def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(), c="red", marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie")
    plt.title("Eboulis des valeurs propres")
    plt.show(block=False)

# %%
display_scree_plot(pca)

# %%
# projection des données sur les features
data_wide_selection = data.filter(std_feature_selection + cat_feat_order)
data_wide_selection.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-e728049be959> in <module>
#       1 # projection des données sur les features
# ----> 2 data_wide_selection = data.filter(std_feature_selection + cat_feat_order)
#       3 data_wide_selection.shape
#
# NameError: name 'std_feature_selection' is not defined

# %%
names = []
for i in range(1, 5):
    elt = 'F' + str(i)
    names.append(elt)

# %%
pca_optimal = PCA(n_components=4)
principalComponents_optimal = pca_optimal.fit_transform(data_selection)
data_optimal = pd.DataFrame(
    data=principalComponents_optimal, columns=names, index=data_selection.index)

# %%
data_optimal.head(5)
# Out:
#          F1        F2        F3        F4
# 0  0.892987 -0.598070 -0.001660 -1.031249
# 1  1.721864  1.464836 -0.760604 -0.423628
# 2 -0.075345  0.875573  0.622205 -0.654445
# 3  4.766141 -1.260071 -0.394819  0.227113
# 4  5.147649 -0.191992 -1.332077  0.920701

# %%
sum(pca_optimal.explained_variance_ratio_)
# Out:
# 0.9611256838727906

# %% [markdown]
# # K - Means

# %% [markdown]
# on réalise un clustering k-means sur les données transformées / PCA

# %%
sse = {}
# silhouette = {}
dbs = {}
for k in range(2, 8):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit_predict(data_optimal)
    # silhouette[k] = metrics.silhouette_score(data_optimal,
    #                                         kmeans.labels_)
    sse[k] = kmeans.inertia_
    dbs[k] = metrics.davies_bouldin_score(
        data_optimal,
        kmeans.labels_)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.grid(False)
ax2.grid(False)
ax1.plot(list(sse.keys()),
         list(sse.values()),
         'v-',
         markersize=10,
         color='steelblue')
ax2.plot(list(dbs.keys()),
         list(dbs.values()),
         '^-',
         markersize=10,
         color='red')
ax1.set_xlabel('Nb of clusters')
ax1.set_ylabel('Elbow criterion', color='steelblue')
ax2.set_ylabel('Davies-Bouldin score', color='red')
plt.show()

# %%
# plt.title('Silhouette Score')
# sns.pointplot(x=list(silhouette.keys()), y=list(silhouette.values()))

# %%
kmeans_optimal = KMeans(n_clusters=3, random_state=42)
kmeans_optimal.fit_predict(data_optimal)
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
kmeans_optimal.inertia_
# Out:
# 310119.506322904

# %%
# afficher les données selon les 2 dimensions
plt.scatter(data_optimal['F1'], data_optimal['F2'], c=kmeans_optimal.labels_.astype(np.float), cmap='viridis', alpha=.2)

# %%
metrics.silhouette_score(data_optimal, kmeans_optimal.labels_)
# Out:
# 0.23374728166611183

# %% [markdown]
# - K-means à partir de données sans PCA

# %%
sse = {}
# silhouette = {}
dbs = {}
for k in range(2, 8):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit_predict(data_selection)
    # silhouette[k] = metrics.silhouette_score(data_selection,
    #                                         kmeans.labels_)
    sse[k] = kmeans.inertia_
    dbs[k] = metrics.davies_bouldin_score(
        data_selection,
        kmeans.labels_)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.grid(False)
ax2.grid(False)
ax1.plot(list(sse.keys()),
         list(sse.values()),
         'v-',
         markersize=10,
         color='steelblue')
ax2.plot(list(dbs.keys()),
         list(dbs.values()),
         '^-',
         markersize=10,
         color='red')
ax1.set_xlabel('Nb of clusters')
ax1.set_ylabel('Elbow criterion', color='steelblue')
ax2.set_ylabel('Davies-Bouldin score', color='red')
plt.show()

# %%
plt.title('Davies-Bouldin Score')
sns.pointplot(x=list(dbs.keys()), y=list(dbs.values()))

# %%
kmeans_optimal = KMeans(n_clusters=2, random_state=42)
kmeans_optimal.fit_predict(data_selection)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kmeans_optimal.inertia_
# Out:
# 423005.451066482

# %%
data_selection
# Out:
#        N_RG_payment_total  N_RG_freight_percentage  N_RG_review_gap  \
# 0               -0.138475                -0.966516         0.679957
# 1               -1.596480                 0.523105        -0.242903
# 2               -0.690965                 0.526175         0.901882
# 3                1.732014                -0.015392        -0.242903
# 4               -0.441374                -0.570629        -1.470545
# ...                   ...                      ...              ...
# 90355            0.487079                -0.142863         0.458679
# 90356           -1.233771                 0.631587        -0.242903
# 90357            0.296485                -0.861281        -0.242903
# 90358           -0.860057                 0.938721        -1.260726
# 90359           -1.298871                 1.575213        -0.242903
#
#        N_RG_delivery_vs_estimated  N_RG_cust_sell_dist
# 0                       -0.870846            -0.778726
# 1                       -1.096804            -1.582677
# 2                       -0.050661            -0.017523
# 3                       -0.987837            -5.199338
# 4                       -1.096804            -5.199338
# ...                           ...                  ...
# 90355                    1.746017             0.970461
# 90356                    2.336331            -0.662794
# 90357                    1.366707            -0.643262
# 90358                    1.639976             0.706750
# 90359                   -0.165327             0.907793
#
# [90360 rows x 5 columns]

# %%
N_RG_payment_total
N_RG_freight_percentage
N_RG_charm_price
N_RG_review_gap
N_RG_delivery_vs_estimated
N_RG_cust_sell_dist

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data_selection['N_RG_payment_total'],
           data_selection['N_RG_freight_percentage'],
           data_selection['N_RG_cust_sell_dist'],
           cmap='plasma',
           c=kmeans_optimal.labels_)
ax.view_init(elev=10, azim=45)
ax.set_xlabel('Rank-Gaussed Payment Total', labelpad=15)
ax.set_ylabel('Rank-Gaussed Freight Percentage', labelpad=15)
ax.set_zlabel('Rank-Gaussed Cust_Sell distance')
# Out:
# Text(0.5, 0, 'Rank-Gaussed Cust_Sell distance')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(data_selection['N_RG_payment_total'],
           data_selection['N_RG_review_gap'],
           data_selection['N_RG_delivery_vs_estimated'],
           cmap='plasma',
           c=kmeans_optimal.labels_)
ax.view_init(elev=10, azim=45)
ax.set_xlabel('Rank-Gaussed Payment Total', labelpad=15)
ax.set_ylabel('Rank-Gaussed Review Gap', labelpad=15)
ax.set_zlabel('Rank-Gaussed Delivery vs Estimated')
# Out:
# Text(0.5, 0, 'Rank-Gaussed Delivery vs Estimated')

# %% [markdown]
# # DBSCAN

# %%
data_sample_20 = pd.DataFrame(data_selection).sample(
    int(data_selection.shape[0]/5),
    random_state=42)
data_sample_20.shape
# Out:
# (18072, 8)

# %%
data_sample_20.sample(3)
# Out:
#        N_RG_payment_total  N_RG_product_review_mean  N_RG_cust_sell_dist  \
# 69559            1.112843                  5.199338             0.032081
# 71457           -1.565098                 -1.895088             1.633426
# 42175           -0.648953                 -0.185223             0.834427
#
#        purchase_time_zone_AM-WD  purchase_time_zone_Evening-WD  \
# 69559                         0                              0
# 71457                         0                              0
# 42175                         0                              0
#
#        purchase_time_zone_Night  purchase_time_zone_PM-WD  \
# 69559                         1                         0
# 71457                         1                         0
# 42175                         0                         1
#
#        purchase_time_zone_WE
# 69559                      0
# 71457                      0
# 42175                      0

# %%
# Compute DBSCAN
db = DBSCAN(eps=1.7, min_samples=8, metric='cityblock').fit(data_sample_20)
labels = db.labels_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 25
# Estimated number of noise points: 25

# %%
print('Silhouette Coefficient: %0.3f'
      % metrics.silhouette_score(data_sample_20, labels))
# Out:
# Silhouette Coefficient: 0.226

# %%
data_sample_20['cluster_dbscan'] = labels

# %%
data_sample_20['cluster_dbscan'].unique()
# Out:
# array([ 0,  1,  2,  3, -1], dtype=int64)

# %%
# observer la répartition des effectifs dans les clusters
data_sample_20['cluster_dbscan'].value_counts(sort=False).plot(
    kind='barh',
    color='steelblue',
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('Cluster pop', labelpad=14)
plt.title('Cluster nb', y=1.02)
# Out:
# Text(0.5, 1.02, 'Cluster nb')

# %% [markdown]
# # K-Modes

# %% [markdown]
# Technique de Clustering dédiée aux features catégoriels. Son inconvenient majeur dans notre contexte, est que la proximité des catégories est perdue : dans le cas de plus de 2 catégories, cela implique que l'algorythme trouvera la même différence, par exemple, entre below median et over median, qu'entre below median et median, tandis que dans les faits, il y a une progression de below median vers over median.
#
# Le principal intérêt est de fournir une description sans équivoque des centroids et une caractéristation très simple des clusters ainsis formés.

# %%
# projection des données sur les features
mode_selection = ['eq_payment_lvl', 'price_charmed', 'purchase_time_zone', 'product_review_mean_lvl']
data_mode_selection = data.filter(mode_selection)
data_mode_selection.shape
# Out:
# (90360, 4)
# 2:80: E501 line too long (101 > 79 characters)

# %%
data_mode_selection.sample(3)
# Out:
#         eq_payment_lvl  price_charmed purchase_time_zone  \
# 57272  OverMed_Payment  price_charmed                 WE
# 59405    Light_Payment  price_charmed              Night
# 80283    Light_Payment  price_charmed         Evening-WD
#
#       product_review_mean_lvl
# 57272               Top_Score
# 59405               Low_Score
# 80283            Medium_Score

# %%
km = KModes(n_clusters=4, init='Huang', n_init=50, verbose=1)

# %%
clusters = km.fit_predict(data_mode_selection)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 24950, cost: 141179.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 14774, cost: 145887.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 7879, cost: 150579.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 10342, cost: 147999.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 142772.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 12219, cost: 140248.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 23244, cost: 140296.0
# Run 7, iteration: 2/100, moves: 2527, cost: 140296.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 12184, cost: 158446.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 13000, cost: 142455.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 0, cost: 155253.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 11, iteration: 1/100, moves: 21437, cost: 137951.0
# Run 11, iteration: 2/100, moves: 13894, cost: 137951.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 12, iteration: 1/100, moves: 0, cost: 146046.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 13, iteration: 1/100, moves: 0, cost: 146854.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 14, iteration: 1/100, moves: 0, cost: 148487.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 15, iteration: 1/100, moves: 0, cost: 150149.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 16, iteration: 1/100, moves: 0, cost: 149322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 17, iteration: 1/100, moves: 16056, cost: 146383.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 18, iteration: 1/100, moves: 17773, cost: 140045.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 19, iteration: 1/100, moves: 0, cost: 146359.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 20, iteration: 1/100, moves: 0, cost: 149279.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 21, iteration: 1/100, moves: 7941, cost: 148419.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 22, iteration: 1/100, moves: 0, cost: 147575.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 23, iteration: 1/100, moves: 0, cost: 142699.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 24, iteration: 1/100, moves: 13872, cost: 137715.0
# Run 24, iteration: 2/100, moves: 604, cost: 137715.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 25, iteration: 1/100, moves: 0, cost: 145304.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 26, iteration: 1/100, moves: 30028, cost: 149984.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 27, iteration: 1/100, moves: 0, cost: 151267.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 28, iteration: 1/100, moves: 25000, cost: 145668.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 29, iteration: 1/100, moves: 13212, cost: 149976.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 30, iteration: 1/100, moves: 4633, cost: 154326.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 31, iteration: 1/100, moves: 13177, cost: 143674.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 32, iteration: 1/100, moves: 12965, cost: 141010.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 33, iteration: 1/100, moves: 16202, cost: 148179.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 34, iteration: 1/100, moves: 4353, cost: 146825.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 35, iteration: 1/100, moves: 0, cost: 156272.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 36, iteration: 1/100, moves: 0, cost: 155018.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 37, iteration: 1/100, moves: 0, cost: 145865.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 38, iteration: 1/100, moves: 0, cost: 151966.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 39, iteration: 1/100, moves: 3889, cost: 147559.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 40, iteration: 1/100, moves: 0, cost: 147073.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 41, iteration: 1/100, moves: 0, cost: 150874.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 42, iteration: 1/100, moves: 0, cost: 148909.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 43, iteration: 1/100, moves: 32811, cost: 142796.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 44, iteration: 1/100, moves: 0, cost: 167229.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 45, iteration: 1/100, moves: 15878, cost: 143288.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 46, iteration: 1/100, moves: 14097, cost: 142531.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 47, iteration: 1/100, moves: 19095, cost: 139971.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 48, iteration: 1/100, moves: 0, cost: 141359.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 49, iteration: 1/100, moves: 0, cost: 139316.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 50, iteration: 1/100, moves: 17715, cost: 145989.0
# Best run was number 24

# %%
# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# [['Light_Payment' 'price_charmed' 'PM-WD' 'Top_Score']
#  ['Heavy_Payment' 'price_charmed' 'Evening-WD' 'Low_Score']
#  ['UnderMed_Payment' 'price_charmed' 'Evening-WD' 'Low_Score']
#  ['OverMed_Payment' 'price_charmed' 'WE' 'Medium_Score']]

# %%
# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# [['Light_Payment' 'Credit_Card_PayType' 'PM-WD' 'Low_Score'
#   'Better_Review' 'price_charmed' 'Far_Dist']
#  ['UnderMed_Payment' 'Credit_Card_PayType' 'Evening-WD' 'Medium_Score'
#   'Worst_Review' 'not_price_charmed' 'Near_Dist']
#  ['OverMed_Payment' 'Credit_Card_PayType' 'Evening-WD' 'Top_Score'
#   'Same_Review' 'price_charmed' 'AroundMed_Dist']
#  ['UnderMed_Payment' 'Other_PayType' 'WE' 'Medium_Score' 'Better_Review'
#   'price_charmed' 'AroundMed_Dist']]

# %%
# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# [['Light_Payment' 'Credit_Card_PayType' 'PM-WD' 'Low_Score'
#   'Better_Review' 'price_charmed' 'Far_Dist']
#  ['UnderMed_Payment' 'Credit_Card_PayType' 'Evening-WD' 'Medium_Score'
#   'Worst_Review' 'not_price_charmed' 'Near_Dist']
#  ['OverMed_Payment' 'Credit_Card_PayType' 'Evening-WD' 'Top_Score'
#   'Same_Review' 'price_charmed' 'AroundMed_Dist']]

# %%
km10 = KModes(n_clusters=5, init='Huang', n_init=10, verbose=1)

# %%
clusters10 = km10.fit_predict(data_mode_selection)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 180549.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 30211, cost: 180127.0
# Run 2, iteration: 2/100, moves: 5553, cost: 180127.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 3657, cost: 177279.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 8526, cost: 183349.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 181246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 15126, cost: 175534.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 27437, cost: 180041.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 32870, cost: 194545.0
# Run 8, iteration: 2/100, moves: 12373, cost: 184587.0
# Run 8, iteration: 3/100, moves: 3957, cost: 184587.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 37374, cost: 190608.0
# Run 9, iteration: 2/100, moves: 2425, cost: 190608.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 14022, cost: 177918.0
# Best run was number 6

# %%
# Print the cluster centroids
print(km10.cluster_centroids_)
# Out:
# [['AroundMed_Paiement' 'Late_Delivery' 'BelowMed_FreightCost' 'Near_Dist'
#   'AroundMed_Review' '1']
#  ['Light_Paiement' 'OnTime_Delivery' 'OverMed_FreightCost' 'Far_Dist'
#   'AroundMed_Review' '1']
#  ['Light_Paiement' 'OnTime_Delivery' 'OverMed_FreightCost'
#   'AroundMed_Dist' 'AroundMed_Review' '0']
#  ['AroundMed_Paiement' 'OnTime_Delivery' 'AroundMed_FreightCost'
#   'AroundMed_Dist' 'AroundMed_Review' '1']
#  ['AroundMed_Paiement' 'Soon_Delivery' 'AroundMed_FreightCost'
#   'Near_Dist' 'UpperMed_Review' '1']]

# %%
km10.labels_
# Out:
# array([0, 0, 3, ..., 0, 1, 1], dtype=uint16)

# %%
KModeClust = data.copy()

# %%
KModeClust['clusters'] = km10.labels_

# %%
# observer la répartition des effectifs dans les clusters
KModeClust['clusters'].value_counts(sort=False).plot(
    kind='barh',
    color='steelblue',
    figsize=(5, 5)).invert_yaxis()
plt.xlabel('Cluster pop', labelpad=14)
plt.title('Cluster nb', y=1.02)
# Out:
# Text(0.5, 1.02, 'Cluster nb')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(KModeClust['N_RG_payment_total'],
           KModeClust['N_RG_freight_percentage'],
           KModeClust['N_RG_cust_sell_dist'],
           cmap='plasma',
           c=KModeClust['clusters'])
ax.view_init(elev=10, azim=45)
ax.set_xlabel('Rank-Gaussed Payment Total', labelpad=15)
ax.set_ylabel('Rank-Gaussed Freight Percentage', labelpad=15)
ax.set_zlabel('Rank-Gaussed Cust_Sell distance')
# Out:
# Text(0.5, 0, 'Rank-Gaussed Cust_Sell distance')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(KModeClust['N_RG_payment_total'],
           KModeClust['N_RG_review_gap'],
           data_selection['N_RG_cust_sell_dist'],
           cmap='plasma',
           c=KModeClust['clusters'])
ax.view_init(elev=10, azim=45)
ax.set_xlabel('Rank-Gaussed Payment Total', labelpad=15)
ax.set_ylabel('Rank-Gaussed Freight Percentage', labelpad=15)
ax.set_zlabel('Rank-Gaussed Cust_Sell distance')
# Out:
# Text(0.5, 0, 'Rank-Gaussed Cust_Sell distance')

# %%
KModeClust.groupby('purchase_time_zone').clusters.value_counts().plot(
        kind='barh',
        color='steelblue',
        figsize=(5, 5)).invert_yaxis()
plt.xlabel('Orders Qty', labelpad=14)
plt.title('Purchase Time Zones', y=1.02)
# Out:
# Text(0.5, 1.02, 'Purchase Time Zones')
