# %%
# %load_ext pycodestyle_magic
# %flake8_on
# la convention PEP8 est ainsi testée
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %%
# importer les packages
# common
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# ml
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
# plot
from mpl_toolkits.mplot3d import Axes3D
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# 1: E999 SyntaxError: invalid syntax

# %%
# récupérer les données
data = pd.read_csv('Data/data.csv')

# %% [markdown]
# # PCA
# On déroule une PCA sur les features numériques

# %%
# cibler les features numériques
num_feat = ['delivery_vs_estimated',
            'freight_percentage',
            'product_name_length',
            'product_description_length',
            'product_photos_qty',
            'product_weight_g',
            'product_size',
            'total_price',
            'total_freight',
            'product_price',
            'product_freight',
            'main_payment_value',
            'payment_sequence_size',
            'payment_installments_size',
            'payment_total',
            'review_score',
            'review_answer_delay',
            'product_review_mean',
            'cust_sell_dist',
            'order_count',
            'items_qty']

# %%
# ajouter le booleen charm price
num_feat.append('charm_price')

# %%
# passer le customer_unique_id en index
data = data.rename(index=data['customer_unique_id'])

# %%
# projeter les données sur les features num
data = data.filter(num_feat, axis=1)

# %%
# contrôler la taille
data.shape
# Out:
# (90355, 8)

# %%
# standardiser les données
data_std = StandardScaler().fit_transform(data)

# %%
# aperçu sur 2 dimensions
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(data_std)
principalDf = pd.DataFrame(
    data=principalComponents, columns=['F1',
                                       'F2'])

# %%
# afficher les données selon les 2 dimensions
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('F1', fontsize=10)
ax.set_ylabel('F2', fontsize=10)
ax.set_title('PCA n_components=2', fontsize=12)

ax.scatter(principalDf['F1'],
           principalDf['F2'], s=50, alpha=0.2)
ax.grid()

# %%
# variance
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.29879705 0.15153527]
# 0.45033232438405035

# %%
# contribution des variables aux 2 composantes
pcs = pca.components_

fig = plt.figure(figsize=(10, 10))
for i, (x, y) in enumerate(zip(pcs[0, :], pcs[1, :])):
    plt.plot([0, x], [0, y])
    plt.text(x, y, data.columns[i])
plt.plot([-0.7, 0.7], [0, 0], color='grey', ls='--')
plt.plot([0, 0], [-0.7, 0.7], color='grey', ls='--')
plt.xlim([-0.5, 0.7])
plt.ylim([-0.7, 0.7])
# Out:
# (-0.7, 0.7)

# %%
# avec 3 composants
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(data_std)
principalDf = pd.DataFrame(
    data=principalComponents, columns=['F1',
                                       'F2',
                                       'F3'])

# %%
# afficher les données selon les 3 dimensions
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.set_xlabel('F1', fontsize=15)
ax.set_ylabel('F2', fontsize=15)
ax.set_zlabel('F3', fontsize=15)
ax.set_title('PCA n_components=3', fontsize=20)

ax.scatter(principalDf['F1'],
           principalDf['F2'],
           principalDf['F3'],
           s=60,
           alpha=0.2)
ax.grid()

# %%
# variance
print(pca.explained_variance_ratio_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [0.29879705 0.15153527 0.14804063]
# 0.5983729517639199

# %%
# nombre optimal de components
pca = PCA()
pca.fit(data_std)
cumsum = np.cumsum(pca.explained_variance_ratio_)

# %%
def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(), c="red", marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie")
    plt.title("Eboulis des valeurs propres")
    plt.show(block=False)

# %%
display_scree_plot(pca)

# %%
# avec une restriction sur les features
num_feat = ['delivery_vs_estimated',
            'freight_percentage',
            'product_weight_g',
            'product_price',
            'payment_total',
            'product_review_mean',
            'cust_sell_dist',
            'items_qty']

# %%
# projeter les données sur les features num
data = data.filter(num_feat, axis=1)

# %%
# contrôler la taille
data.shape
# Out:
# (90355, 12)

# %%
data_std.shape
# Out:
# (90355, 22)
